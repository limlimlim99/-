# %%
# 10.26

# %% [markdown]
# # 한 페이지에 10개씩 들어가 있는 뉴스 제목 10개 추출

# %% [markdown]
# # 네이버 - 우크라이나 - 뉴스제목+url(10개)

# %%
# 네이버 - 우크라이나 - 뉴스
# 짧게 합친 것

# 임포트
from urllib import request
from bs4 import BeautifulSoup

# url 읽어와 html으로 저장
url='https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98'
html=request.urlopen(url).read()

# html 또는 lxml를 BeautifulSoup에 넣어주고, soup로 저장
# html, lxml 둘 중 하나로 하면 됨
soup = BeautifulSoup(html, 'html.parser')
#soup=BeautifulSoup(html, 'lxml')

title= soup.find_all(class_="news_tit")
len(title)  #10개를 추출

title[0]   #첫번째 제목 추출
title[0].text   # title안에 있는 글자만 뽑아낸다
[tit.text for tit in title]   # for문을 이용해 제목 10개 추출

# 제목, 기사 출력
title[0].attrs['href']

# 10개 전부 출력
for i in title:
    print(i.text, ":", i.attrs['href'])

# %%
# 크롤링
# 네이버- '우크라이나' 검색- 뉴스
# 한 페이지에 10개씩 들어가 있는 뉴스 제목을 10페이지=100개를 크롤링
# 맨뒤에있는 query=우크라이나
# 우크라이나를 다른 검색어로 바꿔주면 그 검색어로 크롤링 가능

# %%
# 라이브러리 불러오기
# 그냥 검색해서 url 복붙하면 됨
#https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98

# %%
# 안해도됨 안함
#import urllib.request

# %%
from urllib import request
from bs4 import BeautifulSoup

# %%
url='https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98'
url
# Out:
# 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98'

# %%
# 읽어서 가지고 옴, html으로 저장을 해준다
html= request.urlopen(url).read()
html
# Out:
# b'<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98 : \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4\xea\xb2\x80\xec\x83\x89 \xea\xb2\xb0\xea\xb3\xbc\xec\x9e\x85\xeb\x8b\x88\xeb\x8b\xa4."> <meta name="description" lang="ko" content="\'\xec\x9a\xb0\xed\x81\xac\xeb\x9d\xbc\xec\x9d\xb4\xeb\x82\x98\'\xec\x9d\x98 \xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\x89\xb4\xec\x8a\xa4
# ...

# %%
type(html)
# Out:
# bytes

# %%
# html을 BeautifulSoup에 넣어준다 -> html을 읽을 수 있게 해석해준다 
soup= BeautifulSoup(html,'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
#lxml으로 바꿔보면
#soup= BeautifulSoup(html,'lxml')
#soup
# Out:
# <!DOCTYPE html>
# ...

# %%
soup.find_all("title")
# Out:
# [<title>우크라이나 : 네이버 뉴스검색</title>]

# %%
# 네이버에서 검색 후 
# 창에서 f12를 누르면 오른쪽 마우스 클릭- 검사 를 누른 것과 같음
# news_tit  = 제목임

# %%
# 뉴스 제목을 10개를 가지고 옴, title로 저장을 해줌  
# class이름을 적어주면 다 가져온다
title = soup.find_all(class_ = "news_tit")
title
# class뒤에 _를 넣어줘야함
# Out:
# []

# %%
# title안에는 10개가 있는 것을 알 수 있다.
len(title)
# Out:
# 10

# %%
# 객체가 resultset 이다.
type(title)
# Out:
# bs4.element.ResultSet

# %%
# 객체가 beautifulsoup이다.
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
# title[0] 에는 무엇이 있는자 확인(첫번째 제목)
title[0]
# Out:
# <a class="news_tit" href="http://www.womennews.co.kr/news/articleView.html?idxno=229198" onclick="return goOtherCR(this, 'a=nws*a.tit&amp;r=1&amp;i=88000589_000000000000000000101145&amp;g=310.0000101145&amp;u='+urlencode(this.href));" target="_blank" title="우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상"><mark>우크라이나</mark> 헤르손 탈환 시도...가장 치열한 전투 예상</a>

# %%
# title[0] 안에 있는 글자만 뽑아낸다
title[0].text
# Out:
# '우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상'

# %%
# 루프로 돌리면 10개의 제목만 뽑아낼 수 있다.

# %%
[tit.text for tit in title]
# Out:
# ['우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상',
#  '러, 푸틴 참관 대규모 핵 훈련…"우크라이나 \'더러운 폭탄\' 우려"',
#  '우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부',
#  '전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료',
#  '우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?',
#  '악수하는 독일-우크라이나 대통령',
#  '“감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나',
#  '“유럽 천연가스, 우크라이나 전쟁 이전 수준으로 회귀”',
#  '승리의 V 그리는 우크라이나 전차병',
#  '부산 엑스포 유치전, 우크라이나 ‘복병’ 만났다']

# %%
[title[i].text for i in range(len(title))]
# Out:
# ['우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상',
#  '러, 푸틴 참관 대규모 핵 훈련…"우크라이나 \'더러운 폭탄\' 우려"',
#  '우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부',
#  '전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료',
#  '우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜?',
#  '악수하는 독일-우크라이나 대통령',
#  '“감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나',
#  '“유럽 천연가스, 우크라이나 전쟁 이전 수준으로 회귀”',
#  '승리의 V 그리는 우크라이나 전차병',
#  '부산 엑스포 유치전, 우크라이나 ‘복병’ 만났다']

# %%
# attrs(attribute)
# href= 속성
# <a> 태그의 href 속성은 링크된 페이지의 URL을 명시합니다.
title[0].attrs['href']
# Out:
# 'http://www.womennews.co.kr/news/articleView.html?idxno=229198'

# %%
title[0]['href']
# Out:
# 'http://www.womennews.co.kr/news/articleView.html?idxno=229198'

# %%
title[0].attrs['href']

# 3가지 방법 모두 다 나옴
# Out:
# 'http://www.womennews.co.kr/news/articleView.html?idxno=229198'

# %%
# 제목 + url
for i in title:
    print(i.text, ":", i.attrs['href'])
# Out:
# 우크라이나 헤르손 탈환 시도...가장 치열한 전투 예상 : http://www.womennews.co.kr/news/articleView.html?idxno=229198
# 러, 푸틴 참관 대규모 핵 훈련…"우크라이나 '더러운 폭탄' 우려" : http://news.tvchosun.com/site/data/html_dir/2022/10/27/2022102790031.html
# 우크라이나, 수백만 해외 피란민에 “올겨울엔 귀국 말라” 당부 : https://news.kbs.co.kr/news/view.do?ncd=5587218&ref=A
# 전쟁 피해 한국 온 우크라이나인 뇌출혈…인천시 도움으로 치료 : http://www.newsis.com/view/?id=NISX20221026_0002062855&cID=14001&pID=14000
# 우크라이나 전쟁 후 흑해 돌고래 5만 마리 떼죽음, 왜? : https://view.asiae.co.kr/article/2022102614482734312
# 악수하는 독일-우크라이나 대통령 : http://www.newsis.com/view/?id=NISI20221026_0001114670
# “감당할 수 없다, 귀국하지 마라”...혹독한 겨울 대비 나선 우크라이나 : https://www.khan.co.kr/world/europe-russia/article/202210261512001
# “유럽 천연가스, 우크라이나 전쟁 이전 수준으로 회귀” : http://www.edaily.co.kr/news/newspath.asp?newsid=01275926632497184
# 승리의 V 그리는 우크라이나 전차병 : http://www.newsis.com/view/?id=NISI20221027_0001115701
# 부산 엑스포 유치전, 우크라이나 ‘복병’ 만났다 : https://www.busan.com/view/busan/view.php?code=2022102617265710938

# %%
--------------------------------------------------------------------------------

# %%
# 다음- 러시아 - 뉴스 제목 추출

# %%
# 다음- 러시아 - 뉴스 제목 추출
# 짧게 합친 것

# 임포트
from urllib import request
from bs4 import BeautifulSoup

# url 읽기, html으로 저장
url='https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%9F%AC%EC%8B%9C%EC%95%84'
html= request.urlopen(url).read()

# BeautifulSoup에 넣어서 soup로 저장
soup = BeautifulSoup(html, 'html.parser')

# 뉴스 제목을 추출
# 리스트 형식으로 되어있음, 다음은 크롤링이 불가능함
title= soup.find_all(class_= 'tit_main fn_tit_u')
title

# %% [markdown]
# title=soup.find_all(class_="tit_main fn_fit_u")
# title
#
# find
# find_all
#
# select
# select_one

# %%
#You can find tags:

soup.select
("title")
# [<title>The Dormouse's story</title>]

soup.select
("p:nth-of-type(3)")
# [<p class="story">...</p>]
# Out:
# 'p:nth-of-type(3)'

# %% [markdown]
# # header 쓰기
# - user agent검색
# - "https://www.whatismybrowser.com/detect/what-is-my-user-agent/"에서 나의 주소 복사
# - User Agent :"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"
# - user Agent를 헤더에 넣기

# %%
# 이런식으로 씀(참고)
url = "https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=%EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98"
header = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}
html = requests.get(url, headers=header).text
soup = BeautifulSoup(html, 'html.parser')
title = soup.find_all(class_ = 'news_tit')

# %%
# header를 써서 크롤링
# 네이버는 헤더 없이도 잘 됨
# 네이버 크롤링- "news_tit"
# 프랑스

# %%
# 네이버 - 뉴스 - 프랑스
# 짧게 합친 것

# 임포트
from urllib import request
from bs4 import BeautifulSoup
import requests


url="https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%ED%94%84%EB%9E%91%EC%8A%A4"
# header를 설정해서 사용자 에이전트를 넣어줌
header={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"}

# header를 써서 url 읽기, html으로 저장
html = requests.get(url, headers= header).text
soup=BeautifulSoup(html, 'html.parser') # html을 BeautifulSoup에 넣어 soup로 저장

# 뉴스제목 추출
title= soup.find_all(class_="news_tit")

# 블필요한 문자 제거, 제목, 기사 출력
title[0].attrs['href']

# 제목 + url 추출
for i in title:
    print(i.text, ":", i.attrs['href'])
# Out:
# 유대종 주프랑스 대사, 부산시 명예시민 된다 : http://www.fnnews.com/news/202210280946210351
# 네오위즈 "'P의 거짓', 프랑스 게임쇼 '파리 게임 위크' 참가" : https://www.yna.co.kr/view/AKR20221028049900017?input=1195m
# 韓배드민턴 여자복식 3개조, 나란히 프랑스오픈 8강행 : http://www.newsis.com/view/?id=NISX20221028_0002064962&cID=10501&pID=10500
# 파리 '살롱 뒤 쇼콜라', 초콜릿 의상 입은 프랑스 빙상 여제 : https://www.news1.kr/photos/view/?5653499
# 정부, 독일⋅프랑스와 개인정보보호 힘 모은다 : http://www.kukinews.com/newsView/kuk202210260187
# 보성특산품 프랑스 진출 '청신호' : https://www.asiatoday.co.kr/view.php?key=20221026010013096
# [biz air] 아시아나항공, 에어서울, 에어 프랑스, 인천국제공항 : http://www.bizwnews.com/news/articleView.html?idxno=44199
# 사관학교 방문한 마크롱 프랑스 대통령 : https://www.yna.co.kr/view/PYH20221027255900340?input=1196m
# 프랑스 '노란조끼 시위' 재현되나? 마크롱 '연금개혁' 재추진 : http://news.mt.co.kr/mtview.php?no=2022102711455742536
# ‘몽생미셸 1000주년’…몽생미셸은 어떻게 프랑스 인기 관광지가 됐을까[조현... : https://nownews.seoul.co.kr/news/newsView.php?id=20221028601006&wlog_tag3=naver

# %%
# 다음 크롤링 - "tit_main"
#header 정보를 넣으면 다음 크롤링 가능
# 미국

from urllib import request
from bs4 import BeautifulSoup

url='https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%AF%B8%EA%B5%AD'
header= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}
html = requests.get(url, headers= header).text

type(html)

soup= BeautifulSoup(html, 'html.parser')
title=soup.find_all(class_="tit_main")

len(title)

title[0].text

[tit.text for tit in title] 

title[0].attrs['href']

for i in title:
    print(i.text, ":", i.attrs['href'])
# Out:
# 싱하이밍 대사 "한중관계 가장 큰 외부적 도전은 미국" : http://v.media.daum.net/v/20221026140906800?f=o
# “한국에서 미국 주립대 학위 받아요.” : http://v.media.daum.net/v/20221027030701102?f=o
# 미국, 세계화 반대로 돌아서다 : http://v.media.daum.net/v/20221027115008237?f=o
# 상하이, 미국 압박 속 반도체 인력 훈련 캠퍼스 잇달아 신설 : http://v.media.daum.net/v/20221027114532078?f=o
# 김정은, 미국선거 노리고 7차 핵실험 버튼 누르나 : http://v.media.daum.net/v/20221027091500124?f=o
# 중간선거, 미국의 선택은 : http://v.media.daum.net/v/20221026075237684?f=o
# 캐나다가 먼저 금리인상 속도조절 나섰다…미국도 추종할까? : http://v.media.daum.net/v/20221027093357884?f=o
# [표] 국내투자자 미국 주식투자 상위 종목(26일) : https://cp.news.search.daum.net/p/124963450
# "미국도 얼어붙었다"…美 새집 판매 뚝 떨어졌다 : http://v.media.daum.net/v/20221027101806957?f=o
# 싱하이밍 “북핵 묵인 안 해”…미국엔 작심 비판 : http://v.media.daum.net/v/20221026215911165?f=o

# %%
# 다음 크롤링 
# 러시아(원래 미국이였는데 막혀서 러시아로 함)
# 짧게 합친 것

from urllib import request
from bs4 import BeautifulSoup

url='https://search.daum.net/search?w=news&nil_search=btn&DA=NTB&enc=utf8&cluster=y&cluster_page=1&q=%EB%9F%AC%EC%8B%9C%EC%95%84'
# header를 설정해서 사용자 에이전트를 넣어줌
header={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"}


html=requests.get(url, header).text   # header를 써서 url 읽기, html으로 저장
soup=BeautifulSoup(html, 'html.parser')  # html을 BeautifulSoup에 넣어 soup로 저장

# 뉴스 제목추출 전처리
title=soup.find_all(class_="tit_main fn_tit_u")


title[0].text   # 제목만 추출
title[0].attrs['href']   # url만 추출

# for문으로 제목 10개 다 추출
[tit.text for tit in title]

# 제목 + url 추출
for i in title:
    print(i.text, ":", i.attrs['href'])

# %% [markdown]
#  아래와 같은 종류가 있음
# _all을 쓰면 모두 출력, _one을 쓰면 하나만 출력됨
#
# title=soup.find_all(class_="tit_main fn_fit_u")
# title
#
# find
# find_all
#
# select
# select_one

# %% [markdown]
# - Beautiful Soup은 HTML 및 XML 문서를 구문 분석하기위한 Python 패키지이다. HTML에서 데이터를 추출하는 데 사용할 수있는 구문 분석 된 페이지에 대한 구문 분석 트리를 만들며, 웹 스크래핑에 유용하다.
#
# - find() 함수는 조건을 만족하는 태그를 하나만 가져오는 함수이다.
# - find_all() 함수는 원하는 태그가 여러 개 있을 경우 해당하는 태그를 한꺼번에 가져오는 함수이다.
#
# - 만일 한가지 태그만 찾는 것이 아니라 여러 가지의 태그를 찾아야 하는 상황이라면 어떻게 해야할까? 이 경우 아래처럼 찾고 싶은 태그를 리스트로 find_all() 함수에 넣어주면 된다.
#
#
# - 문장 가져오기 : .string, get_text()
# - 태그 내의 문장을 가져오는 방법에는 .string과 get_text()를 사용하는 방법이 있다.

# %% [markdown]
# # 클래스는 점으로 쓰이고, id는 #으로 쓰인다
# 클래스- '.'
# id - '#'

# %% [markdown]
# # 검사

# %%
# 다음 창에 미국을 검색하고 - 뉴스를 들어가서 - 아무 곳이나 마우스를 갖다 댐 - 마우스 우클릭 - 검사 - 
# - 옆에 창이 뜸 - 창에 아무데나 마우스를 갖다 댐 - 마우스 우클릭- copy - copy selector를 클릭 함
# - 그럼 자동으로 복사가 되어짐 - 주피터로 돌아와서 붙여넣기 하면
# - 아래와 같이 #어쩌고가 뜸 그럼 soup.select에 " "를 해서 넣는다. -끝-

#mArticle > div > div:nth-child(3)

# %%
title= soup.select("#newsColl > div.cont_divider > ul > li:nth-child(2) > div.wrap_cont > a")
title

# %%
# 다음 - 미국
# header, selection 쓰기
# 짧게 합친 것

from urllib import request
from bs4 import BeautifulSoup

url='https://search.daum.net/search?nil_suggest=btn&w=news&DA=SBC&q=%EB%AF%B8%EA%B5%AD'
url

header={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/107.0.0.0 Safari/537.36"}

html= requests.get(url, headers= header).text
html

soup= BeautifulSoup(html, 'html.parser')
soup

title=soup.select(" div.cont_divider > ul > li > div.wrap_cont > a")
title

len(title)

title[0].text

title[0].attrs['href']

# 제목 + url 추출
for i in title:
    print(i.text, ":", i.attrs['href'])
#title= soup.select("#newsColl > div.cont_divider > ul > li:nth-child(2) ")
# 뒤에의 > div.wrap_cont > a를 지우면 더 많이 나오게 됨
# soup.select_one을 하면 1개만 가져올 수 있음
# Out:
# 미국의 대 테러전 중심으로 떠오른 소말리아 : http://v.media.daum.net/v/20221028141136877?f=o
# 미국 핵태세 보고서…핵무기 사용 범위 축소 없었다 : http://v.media.daum.net/v/20221028140846805?f=o
# 미중 갈등에도…중국, 미국 내 유학생 수 12년째 1위 : http://v.media.daum.net/v/20221028133154872?f=o
# 미국 “김정은 핵 사용땐 북한 정권 종말” : http://v.media.daum.net/v/20221028114925907?f=o
# 미국 “인도 · 태평양 핵전력 융통성 있게 전개”… 대북 초강력 경고 : http://v.media.daum.net/v/20221028115459124?f=o
# 중간선거, 미국의 선택은 : http://v.media.daum.net/v/20221026075237684?f=o
# 김정은, 미국선거 노리고 7차 핵실험 버튼 누르나 : http://v.media.daum.net/v/20221027091500124?f=o
# [표] 국내투자자 미국 주식투자 상위 종목(27일) : https://cp.news.search.daum.net/p/125016372
# [나와, 현장] 미국식 전동화와 감성정치/오경진 산업부 기자 : http://v.media.daum.net/v/20221028050412206?f=o
# [쫌아는기자들] 미국 점자책 100달러의 벽 깨는 한국 스타트업 센시 : http://v.media.daum.net/v/20221028101022662?f=o

# %%
-------------------------------------------------------------------

# %% [markdown]
# # 패턴 파악하기

# %% [markdown]
# ## 페이지 추출

# %% [markdown]
# 다음- 우크라이나 검색해보면 url에 맨 마지막이 =우크라이나&p=1라고 나옴
# 페이지를 2페이지로 넘겨보면 - =우크라이나&p=2라고 뜸
# 숫자가 바뀌는 것을 알 수 있음

# %% [markdown]
# url1 = "https://search.daum.net/search?nil_suggest=btn&w=news&DA=PGD&q=
# url2=검색어( %EC%9A%B0%ED%81%AC%EB%9D%BC%EC%9D%B4%EB%82%98 )
# url3=페이지번호( &p=1" )

# %%
url1 ="https://search.daum.net/search?nil_suggest=btn&w=news&DA=PGD&q="
url2= input("검색어를 입력해주세요: ")
url3= "&p="

url= url1+url2+url3+str(1)
print(url)
# Out:
# 검색어를 입력해주세요:  우크라이나
# https://search.daum.net/search?nil_suggest=btn&w=news&DA=PGD&q=우크라이나&p=1

# %%
# 페이지 20페이지 추출
url1 = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q='
url2 = input('검색어를 입력하세요.')
url3 = '&p='

for i in range(1, 21):
    url = url1 + url2 + url3 + str(i)
    html = requests.get(url, headers = header).text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find_all(class_ = 'tit_main fn_tit_u')
    for j in title:
        print(j.text, ' : ', j.attrs['href'])
    print(f'{i}페이지입니다')
    print('-' * 100) 
    
    
# 아래와 같이 20페이지가 나오게 됨
# Out:
# 검색어를 입력하세요. 미국
# 미국의 대 테러전 중심으로 떠오른 소말리아  :  http://v.media.daum.net/v/20221028141136877?f=o
# 미국 핵태세 보고서…핵무기 사용 범위 축소 없었다  :  http://v.media.daum.net/v/20221028140846805?f=o
# 미중 갈등에도…중국, 미국 내 유학생 수 12년째 1위  :  http://v.media.daum.net/v/20221028133154872?f=o
# 미국 “김정은 핵 사용땐 북한 정권 종말”  :  http://v.media.daum.net/v/20221028114925907?f=o
# 미국 “인도 · 태평양 핵전력 융통성 있게 전개”… 대북 초강력 경고  :  http://v.media.daum.net/v/20221028115459124?f=o
# 중간선거, 미국의 선택은  :  http://v.media.daum.net/v/20221026075237684?f=o
# 김정은, 미국선거 노리고 7차 핵실험 버튼 누르나  :  http://v.media.daum.net/v/20221027091500124?f=o
# [표] 국내투자자 미국 주식투자 상위 종목(27일)  :  https://cp.news.search.daum.net/p/125016372
# [나와, 현장] 미국식 전동화와 감성정치/오경진 산업부 기자  :  http://v.media.daum.net/v/20221028050412206?f=o
# [쫌아는기자들] 미국 점자책 100달러의 벽 깨는 한국 스타트업 센시  :  http://v.media.daum.net/v/20221028101022662?f=o
# 1페이지입니다
# ----------------------------------------------------------------------------------------------------
# ...

# %%
# 네이버 뉴스에서 페이지 추출

url_naver1 = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query=%ED%94%84%EB%9E%91%EC%8A%A4&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=77&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all"
url_naver2 = input('검색어를 입력해주세요.')
url_naver3 = "&start="

for i in range(1, 4):
    url = url1 + url2 + url3 + str(i)
    html = requests.get(url, headers = header).text
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find_all(class_ = 'tit_main fn_tit_u')
    for j in title:
        print(j.text, ' : ', j.attrs['href'])
    print(f'{i}페이지입니다')
    print('-' * 100)
# Out:
# 검색어를 입력해주세요. 프랑스
# 미국 합작회사 설립해 기업금융 역량 확대  :  http://v.media.daum.net/v/20221027030804141?f=o
# 싱하이밍 대사 "한중관계 가장 큰 외부적 도전은 미국"  :  http://v.media.daum.net/v/20221026140906800?f=o
# “한국에서 미국 주립대 학위 받아요.”  :  http://v.media.daum.net/v/20221027030701102?f=o
# 미국, 세계화 반대로 돌아서다  :  http://v.media.daum.net/v/20221027115008237?f=o
# 상하이, 미국 압박 속 반도체 인력 훈련 캠퍼스 잇달아 신설  :  http://v.media.daum.net/v/20221027114532078?f=o
# 중간선거, 미국의 선택은  :  http://v.media.daum.net/v/20221026075237684?f=o
# 캐나다가 먼저 금리인상 속도조절 나섰다…미국도 추종할까?  :  http://v.media.daum.net/v/20221027093357884?f=o
# "中 인터넷 댓글부대 미국 중간선거 개입 시도" WSJ  :  http://v.media.daum.net/v/20221027121234182?f=o
# [표] 국내투자자 미국 주식투자 상위 종목(26일)  :  https://cp.news.search.daum.net/p/124963450
# "미국도 얼어붙었다"…美 새집 판매 뚝 떨어졌다  :  http://v.media.daum.net/v/20221027101806957?f=o
# 1페이지입니다
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # def함수 만들어서 검색 추출- 네이버

# %%
def search_naver(keyword, page=10):
    url1 = "https://search.naver.com/search.naver?where=news&sm=tab_pge&query="
    url2 = keyword

    for i in range(0, page):
        url3 = f'&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=61&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all&start={i}1'
        url = url1+url2+url3
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'lxml')
        title = soup.find_all(class_='news_tit')
        for j in title:
            print(j.text, " : ", j.attrs['href'])
        print(f'{i+1}페이지 입니다.')
        print('-'*20)
        print()

# %%
from urllib import request
from bs4 import BeautifulSoup
import requests

url1 = 'https://search.naver.com/search.naver?where=news&sm=tab_pge&query='
url3 = '&sort=0&photo=0&field=0&pd=0&ds=&de=&cluster_rank=31&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:all,a:all'
url4 = '&start='

def search_naver(url2):
    for i in range(1, 21):
        url = url1 + url2 + url3 + url4 + str(i)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            print(j.text, ':', j.attrs['href'])
        print(f'{i}페이지입니다.')
        print('-' * 100)

# %%
search_naver("김연아")
# Out:
# 김연아.고우림, 결혼식 비용 1억 중후반…신혼집은 90평대 한강뷰 : http://news.heraldcorp.com/view.php?ud=20221028000148
# 김연아도 빵 터진 고우림父 축사 어땠길래…"논문 읽고 준비" : https://www.hankyung.com/life/article/2022102662917
# '피겨퀸' 김연아·고우림, 결혼식 비용은 얼마? : https://star.ytn.co.kr/_sn/0117_202210270932045508
# '결혼' 김연아♥고우림, 총 예식 비용은 얼마? : http://starin.edaily.co.kr/news/newspath.asp?newsid=01125046632497184
# 김연아 결혼식때 시아버지 축사에 빵 터졌다..'연아 논문'이 왜 거기서 : http://www.fnnews.com/news/202210270641050055
# '46억' 김연아♥고우림 신혼집… "한 달 관리비만 100만원" : http://moneys.mt.co.kr/news/mwView.php?no=2022102808193031730
# IOC도 주목한 ‘김연아 결혼식’… “아이스 퀸 같았다” : https://www.chosun.com/culture-life/culture_general/2022/10/25/3UMQJSEMSNCMLL2PZQ6SAK4FVE/?utm_source=naver&utm_medium=referral&utm_campaign=naver-news
# 김연아♥고우림, 결혼식 총비용은? "1억 중후반대 추정"[연중플러스] : http://star.mt.co.kr/stview.php?no=2022102723172213006
# ...

# %%
# 저장하기
import pandas as pd
def search_naver(word):
    li1=[]
    li2=[]
    
    for i in range(1, 21):
        url = url1 + word + url3 + url4 + str(i)
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find_all(class_ = 'news_tit')
        for j in title:
            li1.append(j.text)
            li2.append(j.attrs['href'])
        #print(li1)
        #print(li2)
        # 두개의 리스트 붙이기 li1, li2
        # df으로만들기
        data= pd.DataFrame({"제목" : li1, "링크" :li2})
        # csv로 저장하기 -> csv파일로 컴퓨터에 저장이 됨
        data.to_csv(f"{word}.csv")  # word는 변수니까 f"{}해줌
        return data

# %%
search_naver("김연아")
# Out:
#                                         제목  \
# 0     김연아.고우림, 결혼식 비용 1억 중후반…신혼집은 90평대 한강뷰
# 1        김연아도 빵 터진 고우림父 축사 어땠길래…"논문 읽고 준비"
# 2               '피겨퀸' 김연아·고우림, 결혼식 비용은 얼마?
# 3               '결혼' 김연아♥고우림, 총 예식 비용은 얼마?
# 4  김연아 결혼식때 시아버지 축사에 빵 터졌다..'연아 논문'이 왜 거기서
# 5      '46억' 김연아♥고우림 신혼집… "한 달 관리비만 100만원"
# 6          IOC도 주목한 ‘김연아 결혼식’… “아이스 퀸 같았다”
# 7   김연아♥고우림, 결혼식 총비용은? "1억 중후반대 추정"[연중플러스]
# 8               결혼한 피겨여왕 김연아의 첫 활동은…꿈나무 지도
# 9          22억에 사 재테크 성공한 김연아 고급빌라 어떤가 봤더니
#
#                                                   링크
# 0  http://news.heraldcorp.com/view.php?ud=2022102...
# 1  https://www.hankyung.com/life/article/20221026...
# 2  https://star.ytn.co.kr/_sn/0117_20221027093204...
# 3  http://starin.edaily.co.kr/news/newspath.asp?n...
# 4      http://www.fnnews.com/news/202210270641050055
# 5  http://moneys.mt.co.kr/news/mwView.php?no=2022...
# 6  https://www.chosun.com/culture-life/culture_ge...
# 7  http://star.mt.co.kr/stview.php?no=20221027231...
# ...

# %%
res.requests.get(url).text
res.status_code
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [50], in <cell line: 1>()
# ----> 1 res.requests.get(url).text
#       2 res.status_code
#
# NameError: name 'res' is not defined

# %%
# request모듈 사용법
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Response 객체
# # 요청(request)을 보내면 응답(response)을 python 객체로 받는다. 그리고 이 Response 객체는 많은 정보와 기능을 가지고 있다
#
# import requests
#
# response = requests.get("https://google.com")
#
# response.status_code
#
# response = requests.get("https://google.com/user/")
#
# response.status_code
#
# response.request
#
# response.status_code
#
# response.encoding

# %% [markdown]
# # get method로 데이터 보내기
#
# import requests
#
# URL = "http://google.com?user=comp&num=42"
#
# response = requests.get(URL)
#
# print("status code :", response.status_code)

# %% [markdown]
# # Beautiful모듈 사용법
# 제나나 블로그 -'https://jennana.tistory.com/160'

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # soup

# %%
# 이미지 첫 페이지 저장하기
# bts

# %%
url='https://search.naver.com/search.naver?where=image&sm=tab_jum&query=bts'
url
# Out:
# 'https://search.naver.com/search.naver?where=image&sm=tab_jum&query=bts'

# %%
url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query=bts'
url2= input("검색어를 입력해주세요: ")
url3= "&p="

url= url1+url2+url3+str(1)
print(url)
# Out:
# 검색어를 입력해주세요:  bts
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=btsbts&p=1

# %%
url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query=bts'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
images = soup.find_all(class_ = '_image _listImage')
images
# 웹페이지에는 있는데 여기서는 없는 경우가 자주 있다.
# [] 리스트 형식으로 나오면 셀레니움을 함
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 images = soup.find_all(class_ = '_image _listImage')
# ----> 2 images[0]
#
# IndexError: list index out of range

# %% [markdown]
# # selenium(셀레니움)

# %%
# 이미지저장하기

# %%
# selenium 설치
pip install selenium
# Out:
#   Input In [252]
#     pip install selenium
#         ^
# SyntaxError: invalid syntax

# %%
# 불러오기
import selenium

# %%
#https://chromedriver.chromium.org/
#를 설치함 C:/user에 넣음

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome("C:/Users/chromedriver.exe")
driver
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_12088\937435623.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:/Users/chromedriver.exe")
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5ee8fbd8f16a7d58c68724daf12535bc")>

# %%
#driver.close()

# %%
# 다른 크롬 창으로 url 창이 뜸
driver.get(url)

# %%
html=driver.page_source

# %%
soup= BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html data-platform="win32" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/107.0.0.0 safari/537.36" lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="btsbts : 네이버 이미지검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'btsbts'의 네이버 이미지검색 결과입니다." property="og:description"/> <meta content="'btsbts'의 네이버 이미지검색 결과입니다." lang="ko" name="description"/> <title>btsbts : 네이버 이미지검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><li
# ...

# %%
images = soup.find_all(class_ = '_image _listImage')
images
# Out:
# []

# %%
for image in images:
    print(image['src'])

# %%
count = 0
for image in images:
    with urlopen(image['src']) as f:
        with open(f"./bts/{count}.jpg", mode='wb') as h:
            data =f.read()
            h.write(data)            
            count+=1

# %%
# bts파일 만들기
#import os
#os.mkdir("bts")

# %%
from urllib.request import urlopen, urlretrieve

# %%
# 이미지를 검색해서 저장하기 
count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1

# %% [markdown]
# # quote_plus- 한글 가능하게 설정

# %%
# bts말고 한글도 되게 url설정
url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2=quote_plus("bts")
url= url1+url2
print(url)

from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus  # 한글 처리 함수 quote_plus

driver=webdriver.Chrome("C:/Users/chromedriver.exe")
driver

driver.get(url)

html=driver.page_source

#driver.close()

soup= BeautifulSoup(html, 'html.parser')
soup

images = soup.find_all(class_ = '_image _listImage')
images 

for image in images:
    print(image['src'])

count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [72], in <cell line: 3>()
#       1 # bts말고 한글도 되게 url설정
#       2 url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
# ----> 3 url2=quote_plus("bts")
#       4 url= url1+url2
#       5 print(url)
#
# NameError: name 'quote_plus' is not defined

# %%
# bts말고 한글도 되게 url설정
url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2=quote_plus("블랙핑크")
url= url1+url2
print(url)

from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus  # 한글 처리 함수 quote_plus

driver=webdriver.Chrome("C:/Users/chromedriver.exe")
driver

driver.get(url)

html=driver.page_source

#driver.close()

soup= BeautifulSoup(html, 'html.parser')
soup

images = soup.find_all(class_ = '_image _listImage')
images 

for image in images:
    print(image['src'])

count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1
# Out:
# https://search.naver.com/search.naver?where=image&sm=tab_jum&query=%EB%B8%94%EB%9E%99%ED%95%91%ED%81%AC
# C:\Users\user\AppData\Local\Temp\ipykernel_8464\1511533629.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:/Users/chromedriver.exe")

# %% [markdown]
# ▶ 최소코드

# %%
driver=webdriver.Chrome("C:/Users/chromedriver.exe")

url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2=quote_plus("원숭이")
url= url1+url2

driver.get(url)

html=driver.page_source
#driver.close()

soup= BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8464\1302212744.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:/Users/chromedriver.exe")

# %%
driver=webdriver.Chrome("C:/Users/chromedriver.exe")

url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2=quote_plus("사자")
url= url1+url2

driver.get(url)

# 잠깐 자라
import time
time.sleep(2)

# 셀레니움 sleep 잠깐 자라
#from selenium import webdriver
#driver = webdriver.Chrome('chromedriver.exe')
#driver.implicitly_wait(10)

html=driver.page_source
driver.close()

soup= BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8464\3114214965.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:/Users/chromedriver.exe")

# %%
from selenium import webdriver

driver = webdriver.Chrome('chromedriver.exe')
driver.implicitly_wait(10)

# %%
driver=webdriver.Chrome("C:/Users/chromedriver.exe")

url1 ='https://search.naver.com/search.naver?where=image&sm=tab_jum&query='
url2=quote_plus(input("검색어:"))
url= url1+url2

driver.get(url)

# 잠깐 자라
import time
time.sleep(2)

# 셀레니움 sleep 잠깐 자라
#from selenium import webdriver
#driver = webdriver.Chrome('chromedriver.exe')
#driver.implicitly_wait(10)

html=driver.page_source
driver.close()

soup= BeautifulSoup(html, 'html.parser')
images = soup.find_all(class_ = '_image _listImage')

count = 0
for image in images:   # 루프 도는 구문
    urlretrieve(image['src'], f"./bts/{count}.jpg")       
    count+=1
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8464\3146364939.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome("C:/Users/chromedriver.exe")
# 검색어: bts

# %% [markdown]
# # 10.28

# %% [markdown]
# # 주소에서 역대 대통령이름을 추출해주세요
# - 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D'

# %%
# 역대 대통령 이름찾기 방법1
import requests
from bs4 import BeautifulSoup

url = f"https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D"
# print(url)
html = requests.get(url)
soup =  BeautifulSoup(html.text, 'lxml')
# print(soup)
all_text = soup.select('td > b > a')

for a in all_text :
    print(a.text) 
    
#soup.select('상위태그명 > 하위태그명 > 하위태그명')
# Out:
# 이승만
# 윤보선
# 박정희
# 최규하
# 전두환
# 노태우
# 김영삼
# 김대중
# 노무현
# 이명박
# 박근혜
# 문재인
# 윤석열

# %%
# 검사에서 복사해 옴
#mw-content-text > div.mw-parser-output > table:nth-child(6) > tbody > tr:nth-child(3) > td:nth-child(3) > b > a
# 줄이기
# tbody > b > a
# tbod ->tb로 줄임
# all_text=soup.select('tb>b>a')

# %%
# 역대 대통령 이름찾기 방법2
#bs=BeautifulSoup의 약자임
url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D'
html = requests.get(url).text
soup = BeautifulSoup(html, 'lxml')
table = soup.find(class_ = 'wikitable').find_all('b')
name = [i.find('a') for i in table]
name = list(filter(None, name))
[i.text for i in name]
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %%
soup.find(class_='wikitable')
# Out:
# <table class="wikitable" style="text-align: center;" width="100%">
# <tbody><tr>
# <th rowspan="2">대</th>
# <th colspan="3">대통령</th>
# <th colspan="2">임기</th>
# <th rowspan="2">득표율</th>
# <th rowspan="2">정당
# </th></tr>
# <tr>
# <th>사진</th>
# <th colspan="2">이름</th>
# <th>취임일</th>
# <th>퇴임일
# </th></tr>
# <tr>
# <td width="20"><b>1</b>
# </td>
# <td rowspan="3" width="70"><a class="image" href="/wiki/%ED%8C%8C%EC%9D%BC:Rhee_Syng-Man_in_1948.jpg"><img alt="Rhee Syng-Man in 1948.jpg" data-file-height="1229" data-file-width="921" decoding="async" height="133" src="//upload.wikimedia.org/wikipedia/commons/thumb/4/46/Rhee_Syng-Man_in_1948.jpg/100px-Rhee_Syng-Man_in_1948.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/4/46/Rhee_Syng-Man_in_1948.jpg/150px-Rhee_Syng-Man_in_1948.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/4/46/Rhee_Syng-Man_in_1948.jpg/200px-Rhee_Syng-Man_in_1948.jpg 2x" width="100"/></a>
# </td>
# ...

# %%
#b태그만 다 가져와라
# 대통령 앞에 a태그가 있다는 것을 볼 수 있음
table= soup.find(class_= 'wikitable').find_all('b')
table
# Out:
# [<b>1</b>,
#  <b><a href="/wiki/%EC%9D%B4%EC%8A%B9%EB%A7%8C" title="이승만">이승만</a></b>,
#  <b>2</b>,
#  <b>3</b>,
#  <b>4</b>,
#  <b><a href="/wiki/%EC%9C%A4%EB%B3%B4%EC%84%A0" title="윤보선">윤보선</a></b>,
#  <b>5</b>,
#  <b><a href="/wiki/%EB%B0%95%EC%A0%95%ED%9D%AC" title="박정희">박정희</a></b>,
#  <b>6</b>,
#  <b>7</b>,
#  <b>8</b>,
#  <b>9</b>,
#  <b>10</b>,
#  <b><a href="/wiki/%EC%B5%9C%EA%B7%9C%ED%95%98" title="최규하">최규하</a></b>,
#  <b>11</b>,
#  <b><a href="/wiki/%EC%A0%84%EB%91%90%ED%99%98" title="전두환">전두환</a></b>,
#  <b>12</b>,
#  <b>13</b>,
#  <b><a href="/wiki/%EB%85%B8%ED%83%9C%EC%9A%B0" title="노태우">노태우</a></b>,
#  <b>14</b>,
#  <b><a href="/wiki/%EA%B9%80%EC%98%81%EC%82%BC" title="김영삼">김영삼</a></b>,
#  <b>15</b>,
#  <b><a href="/wiki/%EA%B9%80%EB%8C%80%EC%A4%91" title="김대중">김대중</a></b>,
#  <b>16</b>,
#  <b><a href="/wiki/%EB%85%B8%EB%AC%B4%ED%98%84" title="노무현">노무현</a></b>,
#  <b>17</b>,
#  <b><a href="/wiki/%EC%9D%B4%EB%AA%85%EB%B0%95" title="이명박">이명박</a></b>,
#  <b>18</b>,
# ...

# %%
# a를 찾자
name = [i.find('a') for i in table]
#None값을 없애고 이름만 추출
name = list(filter(None, name))
[i.text for i in name]
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %%
# 역대 대통령 이름찾기 방법3
url = 'https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%9C%EB%AF%BC%EA%B5%AD%EC%9D%98_%EB%8C%80%ED%86%B5%EB%A0%B9_%EB%AA%A9%EB%A1%9D'

import requests
from bs4 import BeautifulSoup
import re

html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
names = soup.select('td:nth-child(3) > b > a')
pre_names = [name.attrs['title'] for name in names]
pre_names
# Out:
# ['이승만',
#  '윤보선',
#  '박정희',
#  '최규하',
#  '전두환',
#  '노태우',
#  '김영삼',
#  '김대중',
#  '노무현',
#  '이명박',
#  '박근혜',
#  '문재인',
#  '윤석열']

# %% [markdown]
# # 다음 사이트 로그인하기
