# %%
import pandas as pd
exam=pd.read_csv('exam.csv')
exam
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1    50       98       50
# 1            1   2      1    60       97       60
# 2            2   3      1    45       86       78
# 3            3   4      1    30       98       58
# 4            4   5      2    25       80       65
# 5            5   6      2    50       89       98
# 6            6   7      2    80       90       45
# 7            7   8      2    90       78       25
# 8            8   9      3    20       98       15
# 9            9  10      3    50       98       45
# 10          10  11      3    65       65       65
# 11          11  12      3    45       85       32
# 12          12  13      4    46       98       65
# 13          13  14      4    48       87       12
# 14          14  15      4    75       56       78
# 15          15  16      4    58       98       65
# 16          16  17      5    65       68       98
# 17          17  18      5    80       78       90
# 18          18  19      5    89       68       87
# 19          19  20      5    78       83       58

# %%
exam['class']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# Name: class, dtype: int64

# %%
exam[exam['class']==1]
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60
# 2           2   3      1    45       86       78
# 3           3   4      1    30       98       58

# %%
exam[exam['math']>=50]
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1    50       98       50
# 1            1   2      1    60       97       60
# 5            5   6      2    50       89       98
# 6            6   7      2    80       90       45
# 7            7   8      2    90       78       25
# 9            9  10      3    50       98       45
# 10          10  11      3    65       65       65
# 14          14  15      4    75       56       78
# 15          15  16      4    58       98       65
# 16          16  17      5    65       68       98
# 17          17  18      5    80       78       90
# 18          18  19      5    89       68       87
# 19          19  20      5    78       83       58

# %%
exam[(exam['class']==1) & (exam['math']>=50)]
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60

# %%
exam.query('math>=50 and english>90')
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1    50       98       50
# 1            1   2      1    60       97       60
# 9            9  10      3    50       98       45
# 15          15  16      4    58       98       65

# %%
exam=exam.rename({'class':'nclass'},axis=1)
exam

# %%
exam.rename({'class':'nclass'},axis=1,inplace=True)

# %%
#1반이면서 수학이 50점이상을 df.query()를 이용해 찾기
exam.query('nclass==1 and math>=50')
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 0           0   1       1    50       98       50
# 1           1   2       1    60       97       60

# %%
exam[(exam['nclass'] == 1) & (exam['math'] >= 50)]
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 0           0   1       1    50       98       50
# 1           1   2       1    60       97       60

# %%
exam[(exam['nclass']==1) & (exam['math']>=50)]
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 0           0   1       1    50       98       50
# 1           1   2       1    60       97       60

# %%
exam.query('nclass in [1,3,5]')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 0            0   1       1    50       98       50
# 1            1   2       1    60       97       60
# 2            2   3       1    45       86       78
# 3            3   4       1    30       98       58
# 8            8   9       3    20       98       15
# 9            9  10       3    50       98       45
# 10          10  11       3    65       65       65
# 11          11  12       3    45       85       32
# 16          16  17       5    65       68       98
# 17          17  18       5    80       78       90
# 18          18  19       5    89       68       87
# 19          19  20       5    78       83       58

# %%
exam.query('math>50')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 1            1   2       1    60       97       60
# 6            6   7       2    80       90       45
# 7            7   8       2    90       78       25
# 10          10  11       3    65       65       65
# 14          14  15       4    75       56       78
# 15          15  16       4    58       98       65
# 16          16  17       5    65       68       98
# 17          17  18       5    80       78       90
# 18          18  19       5    89       68       87
# 19          19  20       5    78       83       58

# %%
exam.query('math<50')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 2            2   3       1    45       86       78
# 3            3   4       1    30       98       58
# 4            4   5       2    25       80       65
# 8            8   9       3    20       98       15
# 11          11  12       3    45       85       32
# 12          12  13       4    46       98       65
# 13          13  14       4    48       87       12

# %%
exam.query('nclass==1 & math>=50')
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 0           0   1       1    50       98       50
# 1           1   2       1    60       97       60

# %%
exam.query('nclass==2 & math>=80')
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 6           6   7       2    80       90       45
# 7           7   8       2    90       78       25

# %%
exam.query('nclass==1|nclass==3|nclass==5')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 0            0   1       1    50       98       50
# 1            1   2       1    60       97       60
# 2            2   3       1    45       86       78
# 3            3   4       1    30       98       58
# 8            8   9       3    20       98       15
# 9            9  10       3    50       98       45
# 10          10  11       3    65       65       65
# 11          11  12       3    45       85       32
# 16          16  17       5    65       68       98
# 17          17  18       5    80       78       90
# 18          18  19       5    89       68       87
# 19          19  20       5    78       83       58

# %%
import pandas as pd
exam=pd.read_csv('exam.csv')
exam
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1    50       98       50
# 1            1   2      1    60       97       60
# 2            2   3      1    45       86       78
# 3            3   4      1    30       98       58
# 4            4   5      2    25       80       65
# 5            5   6      2    50       89       98
# 6            6   7      2    80       90       45
# 7            7   8      2    90       78       25
# 8            8   9      3    20       98       15
# 9            9  10      3    50       98       45
# 10          10  11      3    65       65       65
# 11          11  12      3    45       85       32
# 12          12  13      4    46       98       65
# 13          13  14      4    48       87       12
# 14          14  15      4    75       56       78
# 15          15  16      4    58       98       65
# 16          16  17      5    65       68       98
# 17          17  18      5    80       78       90
# 18          18  19      5    89       68       87
# 19          19  20      5    78       83       58

# %%
exam.head()
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60
# 2           2   3      1    45       86       78
# 3           3   4      1    30       98       58
# 4           4   5      2    25       80       65

# %%
exam.head(10)
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60
# 2           2   3      1    45       86       78
# 3           3   4      1    30       98       58
# 4           4   5      2    25       80       65
# 5           5   6      2    50       89       98
# 6           6   7      2    80       90       45
# 7           7   8      2    90       78       25
# 8           8   9      3    20       98       15
# 9           9  10      3    50       98       45

# %%
exam.tail(10)
# Out:
#     Unnamed: 0  id  class  math  english  science
# 10          10  11      3    65       65       65
# 11          11  12      3    45       85       32
# 12          12  13      4    46       98       65
# 13          13  14      4    48       87       12
# 14          14  15      4    75       56       78
# 15          15  16      4    58       98       65
# 16          16  17      5    65       68       98
# 17          17  18      5    80       78       90
# 18          18  19      5    89       68       87
# 19          19  20      5    78       83       58

# %%
exam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  20 non-null     int64
#  1   id          20 non-null     int64
#  2   class       20 non-null     int64
#  3   math        20 non-null     int64
#  4   english     20 non-null     int64
#  5   science     20 non-null     int64
# dtypes: int64(6)
# memory usage: 1.1 KB

# %%
exam.describe()
# Out:
#        Unnamed: 0        id      class       math    english    science
# count    20.00000  20.00000  20.000000  20.000000  20.000000  20.000000
# mean      9.50000  10.50000   3.000000  57.450000  84.900000  59.450000
# std       5.91608   5.91608   1.450953  20.299015  12.875517  25.292968
# min       0.00000   1.00000   1.000000  20.000000  56.000000  12.000000
# 25%       4.75000   5.75000   2.000000  45.750000  78.000000  45.000000
# 50%       9.50000  10.50000   3.000000  54.000000  86.500000  62.500000
# 75%      14.25000  15.25000   4.000000  75.750000  98.000000  78.000000
# max      19.00000  20.00000   5.000000  90.000000  98.000000  98.000000

# %%
import numpy as np

# %%
pip install pydataset
# Out:
# Requirement already satisfied: pydataset in c:\users\user\anaconda3\lib\site-packages (0.2.0)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (from pydataset) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->pydataset) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas->pydataset) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from pandas->pydataset) (1.21.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->pydataset) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydataset

# %%
mpg=pydataset.data("mpg")

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
mpg.tail()
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize

# %%
mpg.shape
# Out:
# (234, 11)

# %%
mpg.describe(include='all')
# Out:
#        manufacturer        model       displ         year         cyl  \
# count           234          234  234.000000   234.000000  234.000000
# unique           15           38         NaN          NaN         NaN
# top           dodge  caravan 2wd         NaN          NaN         NaN
# freq             37           11         NaN          NaN         NaN
# mean            NaN          NaN    3.471795  2003.500000    5.888889
# std             NaN          NaN    1.291959     4.509646    1.611534
# min             NaN          NaN    1.600000  1999.000000    4.000000
# 25%             NaN          NaN    2.400000  1999.000000    4.000000
# 50%             NaN          NaN    3.300000  2003.500000    6.000000
# 75%             NaN          NaN    4.600000  2008.000000    8.000000
# max             NaN          NaN    7.000000  2008.000000    8.000000
#
#            trans  drv         cty         hwy   fl class
# count        234  234  234.000000  234.000000  234   234
# unique        10    3         NaN         NaN    5     7
# top     auto(l4)    f         NaN         NaN    r   suv
# freq          83  106         NaN         NaN  168    62
# mean         NaN  NaN   16.858974   23.440171  NaN   NaN
# std          NaN  NaN    4.255946    5.954643  NaN   NaN
# min          NaN  NaN    9.000000   12.000000  NaN   NaN
# 25%          NaN  NaN   14.000000   18.000000  NaN   NaN
# 50%          NaN  NaN   17.000000   24.000000  NaN   NaN
# 75%          NaN  NaN   19.000000   27.000000  NaN   NaN
# max          NaN  NaN   35.000000   44.000000  NaN   NaN

# %%
sum(var)
max(var)
# Out:
# 3

# %%
import pandas as pd
pd.read_csv('exam.csv')
pd.DataFrame({'x':[1,2,3]})
# Out:
#    x
# 0  1
# 1  2
# 2  3

# %%
df.head()
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   var1      3 non-null      int64
#  1   var2      3 non-null      int64
#  2   var_sum   3 non-null      int64
#  3   var_mean  3 non-null      float64
# dtypes: float64(1), int64(3)
# memory usage: 224.0 bytes

# %%
df=pd.read_csv('exam.csv')
df.head()
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60
# 2           2   3      1    45       86       78
# 3           3   4      1    30       98       58
# 4           4   5      2    25       80       65

# %%
var=[1,2,3]
var.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [183], in <cell line: 2>()
#       1 var=[1,2,3]
# ----> 2 var.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(var)
# Out:
# list

# %%
df.head()
# Out:
#    Unnamed: 0  id  class  math  english  science
# 0           0   1      1    50       98       50
# 1           1   2      1    60       97       60
# 2           2   3      1    45       86       78
# 3           3   4      1    30       98       58
# 4           4   5      2    25       80       65

# %%
df.shape
# Out:
# (20, 6)

# %%
var.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [188], in <cell line: 1>()
# ----> 1 var.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
df_raw=pd.DataFrame({'var1':[1,2,1],
                    'var2':[2,3,2]})
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new=df_raw.copy()
df_new
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new=df_new.rename(columns={'var2':'v2'})
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
df_raw
# Out:
#    var1  var2
# 0     1     2
# 1     2     3
# 2     1     2

# %%
df_new
# Out:
#    var1  v2
# 0     1   2
# 1     2   3
# 2     1   2

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# 230  midsize
# 231  midsize
# 232  midsize
# 233  midsize
# 234  midsize
#
# [234 rows x 11 columns]

# %%
mpg=pd.read_csv('mpg.csv')

# %%
mpg.to_csv("mpg.csv")

# %%
mpg=pd.read_csv('mpg.csv')
mpg_new=mpg.copy()

# %%
mpg_new
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer   model  displ  year  \
# 0               0             0           1         audi      a4    1.8  1999
# 1               1             1           2         audi      a4    1.8  1999
# 2               2             2           3         audi      a4    2.0  2008
# 3               3             3           4         audi      a4    2.0  2008
# 4               4             4           5         audi      a4    2.8  1999
# ..            ...           ...         ...          ...     ...    ...   ...
# 229           229           229         230   volkswagen  passat    2.0  2008
# 230           230           230         231   volkswagen  passat    2.0  2008
# 231           231           231         232   volkswagen  passat    2.8  1999
# 232           232           232         233   volkswagen  passat    2.8  1999
# 233           233           233         234   volkswagen  passat    3.6  2008
#
#      cyl       trans drv  cty  hwy fl    class
# 0      4    auto(l5)   f   18   29  p  compact
# 1      4  manual(m5)   f   21   29  p  compact
# 2      4  manual(m6)   f   20   31  p  compact
# 3      4    auto(av)   f   21   30  p  compact
# 4      6    auto(l5)   f   16   26  p  compact
# ..   ...         ...  ..  ...  ... ..      ...
# 229    4    auto(s6)   f   19   28  p  midsize
# 230    4  manual(m6)   f   21   29  p  midsize
# 231    6    auto(l5)   f   16   26  p  midsize
# 232    6  manual(m5)   f   18   26  p  midsize
# 233    6    auto(s6)   f   17   26  p  midsize
#
# [234 rows x 14 columns]

# %%
mpg=pd.read_csv('mpg.csv')
mpg
# Out:
#      Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer   model  displ  year  \
# 0               0             0           1         audi      a4    1.8  1999
# 1               1             1           2         audi      a4    1.8  1999
# 2               2             2           3         audi      a4    2.0  2008
# 3               3             3           4         audi      a4    2.0  2008
# 4               4             4           5         audi      a4    2.8  1999
# ..            ...           ...         ...          ...     ...    ...   ...
# 229           229           229         230   volkswagen  passat    2.0  2008
# 230           230           230         231   volkswagen  passat    2.0  2008
# 231           231           231         232   volkswagen  passat    2.8  1999
# 232           232           232         233   volkswagen  passat    2.8  1999
# 233           233           233         234   volkswagen  passat    3.6  2008
#
#      cyl       trans drv  cty  hwy fl    class
# 0      4    auto(l5)   f   18   29  p  compact
# 1      4  manual(m5)   f   21   29  p  compact
# 2      4  manual(m6)   f   20   31  p  compact
# 3      4    auto(av)   f   21   30  p  compact
# 4      6    auto(l5)   f   16   26  p  compact
# ..   ...         ...  ..  ...  ... ..      ...
# 229    4    auto(s6)   f   19   28  p  midsize
# 230    4  manual(m6)   f   21   29  p  midsize
# 231    6    auto(l5)   f   16   26  p  midsize
# 232    6  manual(m5)   f   18   26  p  midsize
# 233    6    auto(s6)   f   17   26  p  midsize
#
# [234 rows x 14 columns]

# %%
mpg_new=mpg_new.rename(columns={'cty':'city'})
mpg_new=mpg_new.rename(columns={'hwy':'highway'})

# %%
mpg_new.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer model  displ  year  \
# 0             0             0           1         audi    a4    1.8  1999
# 1             1             1           2         audi    a4    1.8  1999
# 2             2             2           3         audi    a4    2.0  2008
# 3             3             3           4         audi    a4    2.0  2008
# 4             4             4           5         audi    a4    2.8  1999
#
#    cyl       trans drv  city  highway fl    class
# 0    4    auto(l5)   f    18       29  p  compact
# 1    4  manual(m5)   f    21       29  p  compact
# 2    4  manual(m6)   f    20       31  p  compact
# 3    4    auto(av)   f    21       30  p  compact
# 4    6    auto(l5)   f    16       26  p  compact

# %%
df=pd.DataFrame({'var1':[4,3,8],
                'var2':[2,6,1]})
df
# Out:
#    var1  var2
# 0     4     2
# 1     3     6
# 2     8     1

# %%
df['var_sum']=df['var1']+df['var2']
df
# Out:
#    var1  var2  var_sum
# 0     4     2        6
# 1     3     6        9
# 2     8     1        9

# %%
df['var_mean']=(df['var1']+df['var2'])/2
df
# Out:
#    var1  var2  var_sum  var_mean
# 0     4     2        6       3.0
# 1     3     6        9       4.5
# 2     8     1        9       4.5

# %%
mpg['total']=(mpg['cty']+mpg['hwy'])/2
mpg.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer model  displ  year  \
# 0             0             0           1         audi    a4    1.8  1999
# 1             1             1           2         audi    a4    1.8  1999
# 2             2             2           3         audi    a4    2.0  2008
# 3             3             3           4         audi    a4    2.0  2008
# 4             4             4           5         audi    a4    2.8  1999
#
#    cyl       trans drv  cty  hwy fl    class  total
# 0    4    auto(l5)   f   18   29  p  compact   23.5
# 1    4  manual(m5)   f   21   29  p  compact   25.0
# 2    4  manual(m6)   f   20   31  p  compact   25.5
# 3    4    auto(av)   f   21   30  p  compact   25.5
# 4    6    auto(l5)   f   16   26  p  compact   21.0

# %%
sum(mpg['total'])/len(mpg)
# Out:
# 20.14957264957265

# %%
mpg['total'].mean()
# Out:
# 20.14957264957265

# %%
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
mpg['total'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import numpy as np

# %%
mpg['test']=np.where(mpg['total']>=20,'pass','fail')

# %%
mpg['test']
# Out:
# 0      pass
# 1      pass
# 2      pass
# 3      pass
# 4      pass
#        ...
# 229    pass
# 230    pass
# 231    pass
# 232    pass
# 233    pass
# Name: test, Length: 234, dtype: object

# %%
mpg.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer model  displ  year  \
# 0             0             0           1         audi    a4    1.8  1999
# 1             1             1           2         audi    a4    1.8  1999
# 2             2             2           3         audi    a4    2.0  2008
# 3             3             3           4         audi    a4    2.0  2008
# 4             4             4           5         audi    a4    2.8  1999
#
#    cyl       trans drv  cty  hwy fl    class  total  test
# 0    4    auto(l5)   f   18   29  p  compact   23.5  pass
# 1    4  manual(m5)   f   21   29  p  compact   25.0  pass
# 2    4  manual(m6)   f   20   31  p  compact   25.5  pass
# 3    4    auto(av)   f   21   30  p  compact   25.5  pass
# 4    6    auto(l5)   f   16   26  p  compact   21.0  pass

# %%
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
count_test=mpg['test'].value_counts()

# %%
count_test.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
mpg['grade']=np.where(mpg['total']>=30,'A',
                     np.where(mpg['total']>=20,'B','C'))

# %%
mpg.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer model  displ  year  \
# 0             0             0           1         audi    a4    1.8  1999
# 1             1             1           2         audi    a4    1.8  1999
# 2             2             2           3         audi    a4    2.0  2008
# 3             3             3           4         audi    a4    2.0  2008
# 4             4             4           5         audi    a4    2.8  1999
#
#    cyl       trans drv  cty  hwy fl    class  total  test grade
# 0    4    auto(l5)   f   18   29  p  compact   23.5  pass     B
# 1    4  manual(m5)   f   21   29  p  compact   25.0  pass     B
# 2    4  manual(m6)   f   20   31  p  compact   25.5  pass     B
# 3    4    auto(av)   f   21   30  p  compact   25.5  pass     B
# 4    6    auto(l5)   f   16   26  p  compact   21.0  pass     B

# %%
count_grade=mpg['grade'].value_counts()
count_grade
# Out:
# B    118
# C    106
# A     10
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
count_grade=mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# A     10
# B    118
# C    106
# Name: grade, dtype: int64

# %%
count_grade.plot.bar(rot=0)
# Out:
# <AxesSubplot:>

# %%
df=mpg['grade']
df=df.value_counts()
df=df.sort_index()

# %%
df=mpg['grade'].value_counts().sort_index()

# %%
mpg['grade2']=np.where(mpg['total']>=30,'A',
                      np.where(mpg['total']>=25,'B',
                              np.where(mpg['total']>=20,'C','D')))
mpg['grade2']
# Out:
# 0      C
# 1      B
# 2      B
# 3      B
# 4      C
#       ..
# 229    C
# 230    B
# 231    C
# 232    C
# 233    C
# Name: grade2, Length: 234, dtype: object

# %%
import pandas as pd
exam=pd.read_csv('exam.csv')
exam
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1    50       98       50
# 1            1   2      1    60       97       60
# 2            2   3      1    45       86       78
# 3            3   4      1    30       98       58
# 4            4   5      2    25       80       65
# 5            5   6      2    50       89       98
# 6            6   7      2    80       90       45
# 7            7   8      2    90       78       25
# 8            8   9      3    20       98       15
# 9            9  10      3    50       98       45
# 10          10  11      3    65       65       65
# 11          11  12      3    45       85       32
# 12          12  13      4    46       98       65
# 13          13  14      4    48       87       12
# 14          14  15      4    75       56       78
# 15          15  16      4    58       98       65
# 16          16  17      5    65       68       98
# 17          17  18      5    80       78       90
# 18          18  19      5    89       68       87
# 19          19  20      5    78       83       58

# %%
exam=exam.rename({'class':'nclass'},axis=1)

# %%
exam.query('nclass==1')
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 0           0   1       1    50       98       50
# 1           1   2       1    60       97       60
# 2           2   3       1    45       86       78
# 3           3   4       1    30       98       58

# %%
exam.query('nclass==2')
# Out:
#    Unnamed: 0  id  nclass  math  english  science
# 4           4   5       2    25       80       65
# 5           5   6       2    50       89       98
# 6           6   7       2    80       90       45
# 7           7   8       2    90       78       25

# %%
exam.query('nclass ! =1')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 4            4   5       2    25       80       65
# 5            5   6       2    50       89       98
# 6            6   7       2    80       90       45
# 7            7   8       2    90       78       25
# 8            8   9       3    20       98       15
# 9            9  10       3    50       98       45
# 10          10  11       3    65       65       65
# 11          11  12       3    45       85       32
# 12          12  13       4    46       98       65
# 13          13  14       4    48       87       12
# 14          14  15       4    75       56       78
# 15          15  16       4    58       98       65
# 16          16  17       5    65       68       98
# 17          17  18       5    80       78       90
# 18          18  19       5    89       68       87
# 19          19  20       5    78       83       58

# %%
exam.query('english<=80')
# Out:
#     Unnamed: 0  id  nclass  math  english  science
# 4            4   5       2    25       80       65
# 7            7   8       2    90       78       25
# 10          10  11       3    65       65       65
# 14          14  15       4    75       56       78
# 16          16  17       5    65       68       98
# 17          17  18       5    80       78       90
# 18          18  19       5    89       68       87

# %%
exam.query('nclass==1 & math>=50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('math>=90 | english >=90')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 3    4       1    30       98       58
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 12  13       4    46       98       65
# 15  16       4    58       98       65

# %%
exam.query('nclass==1|nclass==3|nclass==5')
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
nclass1=exam.query('nclass==1')

# %%
nclass2=exam.query('nclass==2')

# %%
nclass1['math'].mean()
# Out:
# 46.25

# %%
nclass2['math'].mean()
# Out:
# 61.25

# %%
df=pd.DataFrame({'sex' : ['F','M','F','M'],
                'country': ['Korea','China','Japen','USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japen
# 3   M     USA

# %%
df.query('sex=="F" & country=="Korea"')
# Out:
#   sex country
# 0   F   Korea

# %%
df.query("sex=='M' & country=='China'")
# Out:
#   sex country
# 1   M   China

# %%
var=3
exam.query('nclass==@var')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %% [raw]
# pd.set_option('display.max_row',none)
# pd.set_option('display.max_colums',none)

# %%
mpg=pd.read_csv('mpg.csv')
mpg_a=mpg.query('displ<=4')
mpg_b=mpg.query('displ>=5')

# %%
mpg_a['hwy'].mean()
# Out:
# 25.96319018404908

# %%
mpg_b['hwy'].mean
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 18     20
# 19     15
# 20     20
# 21     17
# 22     17
# 23     26
# 24     23
# 25     26
# 26     25
# 27     24
# 28     19
# 29     14
# 30     15
# 31     17
# 55     17
# 56     15
# 61     16
# 62     18
# 63     15
# 70     15
# 71     16
# 72     17
# 73     15
# 75     17
# 76     18
# 82     17
# 88     15
# 89     17
# 98     20
# 128    18
# 129    14
# 134    17
# 135    16
# 136    18
# 140    17
# 153    18
# 158    25
# 199    18
# Name: hwy, dtype: int64>

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
exam['english']
# Out:
# 0     98
# 1     97
# 2     86
# 3     98
# 4     80
# 5     89
# 6     90
# 7     78
# 8     98
# 9     98
# 10    65
# 11    85
# 12    98
# 13    87
# 14    56
# 15    98
# 16    68
# 17    78
# 18    68
# 19    83
# Name: english, dtype: int64

# %%
exam[['nclass','math','english']]
# Out:
#     nclass  math  english
# 0        1    50       98
# 1        1    60       97
# 2        1    45       86
# 3        1    30       98
# 4        2    25       80
# 5        2    50       89
# 6        2    80       90
# 7        2    90       78
# 8        3    20       98
# 9        3    50       98
# 10       3    65       65
# 11       3    45       85
# 12       4    46       98
# 13       4    48       87
# 14       4    75       56
# 15       4    58       98
# 16       5    65       68
# 17       5    80       78
# 18       5    89       68
# 19       5    78       83

# %%
exam.drop(columns='math')
# Out:
#     id  nclass  english  science
# 0    1       1       98       50
# 1    2       1       97       60
# 2    3       1       86       78
# 3    4       1       98       58
# 4    5       2       80       65
# 5    6       2       89       98
# 6    7       2       90       45
# 7    8       2       78       25
# 8    9       3       98       15
# 9   10       3       98       45
# 10  11       3       65       65
# 11  12       3       85       32
# 12  13       4       98       65
# 13  14       4       87       12
# 14  15       4       56       78
# 15  16       4       98       65
# 16  17       5       68       98
# 17  18       5       78       90
# 18  19       5       68       87
# 19  20       5       83       58

# %%
exam.drop(columns=['math','english'])
# Out:
#     id  nclass  science
# 0    1       1       50
# 1    2       1       60
# 2    3       1       78
# 3    4       1       58
# 4    5       2       65
# 5    6       2       98
# 6    7       2       45
# 7    8       2       25
# 8    9       3       15
# 9   10       3       45
# 10  11       3       65
# 11  12       3       32
# 12  13       4       65
# 13  14       4       12
# 14  15       4       78
# 15  16       4       65
# 16  17       5       98
# 17  18       5       90
# 18  19       5       87
# 19  20       5       58

# %%
exam.query('nclass==1')['english']
# Out:
# 0    98
# 1    97
# 2    86
# 3    98
# Name: english, dtype: int64

# %%
exam.query('math>=50')\
[['id','math']]\
.head(10)
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65

# %%
mpg=pd.read_csv('mpg.csv')
mpg_new=mpg[['category','cty']]
mpg_new.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [290], in <cell line: 2>()
#       1 mpg=pd.read_csv('mpg.csv')
# ----> 2 mpg_new=mpg[['category','cty']]
#       3 mpg_new.head()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['category'] not in index"

# %%
exam.sort_values(['nclass','math'])
# Out:
#     id  nclass  math  english  science
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 11  12       3    45       85       32
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 15  16       4    58       98       65
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 19  20       5    78       83       58
# 17  18       5    80       78       90
# 18  19       5    89       68       87

# %%
mpg=pd.read_csv('mpg.csv')
mpg.query('manufacturer=="audi"')\
.sort_values('hwy',ascending=False)\
.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0 manufacturer       model  displ  \
# 2             2             2           3         audi          a4    2.0
# 3             3             3           4         audi          a4    2.0
# 0             0             0           1         audi          a4    1.8
# 1             1             1           2         audi          a4    1.8
# 9             9             9          10         audi  a4 quattro    2.0
#
#    year  cyl       trans drv  cty  hwy fl    class
# 2  2008    4  manual(m6)   f   20   31  p  compact
# 3  2008    4    auto(av)   f   21   30  p  compact
# 0  1999    4    auto(l5)   f   18   29  p  compact
# 1  1999    4  manual(m5)   f   21   29  p  compact
# 9  2008    4  manual(m6)   4   20   28  p  compact

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# 19  20       5    78       83       58    219

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'],
            mean=(exam['math']+exam['english']+exam['science'])/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
import numpy as np
exam.assign(test=np.where(exam['science']>=60,'pass','fail'))
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  fail
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  pass
# 3    4       1    30       98       58  fail
# 4    5       2    25       80       65  pass
# 5    6       2    50       89       98  pass
# 6    7       2    80       90       45  fail
# 7    8       2    90       78       25  fail
# 8    9       3    20       98       15  fail
# 9   10       3    50       98       45  fail
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fail
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fail
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  fail

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'])\
.sort_values('total')
# Out:
#     id  nclass  math  english  science  total
# 8    9       3    20       98       15    133
# 13  14       4    48       87       12    147
# 11  12       3    45       85       32    162
# 4    5       2    25       80       65    170
# 3    4       1    30       98       58    186
# 9   10       3    50       98       45    193
# 7    8       2    90       78       25    193
# 10  11       3    65       65       65    195
# 0    1       1    50       98       50    198
# 2    3       1    45       86       78    209
# 12  13       4    46       98       65    209
# 14  15       4    75       56       78    209
# 6    7       2    80       90       45    215
# 1    2       1    60       97       60    217
# 19  20       5    78       83       58    219
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 5    6       2    50       89       98    237
# 18  19       5    89       68       87    244
# 17  18       5    80       78       90    248

# %%
long_name=pd.read_csv('exam.csv')

# %%
long_name.assign(new=long_name['math']+long_name['english']+long_name['science'])
# Out:
#     Unnamed: 0  id  class  math  english  science  new
# 0            0   1      1    50       98       50  198
# 1            1   2      1    60       97       60  217
# 2            2   3      1    45       86       78  209
# 3            3   4      1    30       98       58  186
# 4            4   5      2    25       80       65  170
# 5            5   6      2    50       89       98  237
# 6            6   7      2    80       90       45  215
# 7            7   8      2    90       78       25  193
# 8            8   9      3    20       98       15  133
# 9            9  10      3    50       98       45  193
# 10          10  11      3    65       65       65  195
# 11          11  12      3    45       85       32  162
# 12          12  13      4    46       98       65  209
# 13          13  14      4    48       87       12  147
# 14          14  15      4    75       56       78  209
# 15          15  16      4    58       98       65  221
# 16          16  17      5    65       68       98  231
# 17          17  18      5    80       78       90  248
# 18          18  19      5    89       68       87  244
# 19          19  20      5    78       83       58  219

# %%
exam.assign(total=exam['math']+exam['english']+exam['science'],mean=lambda x:x['total']/3)
# Out:
#     id  nclass  math  english  science  total       mean
# 0    1       1    50       98       50    198  66.000000
# 1    2       1    60       97       60    217  72.333333
# 2    3       1    45       86       78    209  69.666667
# 3    4       1    30       98       58    186  62.000000
# 4    5       2    25       80       65    170  56.666667
# 5    6       2    50       89       98    237  79.000000
# 6    7       2    80       90       45    215  71.666667
# 7    8       2    90       78       25    193  64.333333
# 8    9       3    20       98       15    133  44.333333
# 9   10       3    50       98       45    193  64.333333
# 10  11       3    65       65       65    195  65.000000
# 11  12       3    45       85       32    162  54.000000
# 12  13       4    46       98       65    209  69.666667
# 13  14       4    48       87       12    147  49.000000
# 14  15       4    75       56       78    209  69.666667
# 15  16       4    58       98       65    221  73.666667
# 16  17       5    65       68       98    231  77.000000
# 17  18       5    80       78       90    248  82.666667
# 18  19       5    89       68       87    244  81.333333
# 19  20       5    78       83       58    219  73.000000

# %%
exam.agg(mean_math=('math','mean'))
# Out:
#             math
# mean_math  57.45

# %%
exam.groupby('nclass')\
.agg(mean_math=('math','mean'))
# Out:
#         mean_math
# nclass
# 1           46.25
# 2           61.25
# 3           45.00
# 4           56.75
# 5           78.00

# %%
exam.groupby('nclass').mean()
# Out:
#           id   math  english  science
# nclass
# 1        2.5  46.25    94.75    61.50
# 2        6.5  61.25    84.25    58.25
# 3       10.5  45.00    86.50    39.25
# 4       14.5  56.75    84.75    55.00
# 5       18.5  78.00    74.25    83.25

# %%
mpg.groupby('drv')\
.agg(n=('drv','count'))
# Out:
#        n
# drv
# 4    103
# f    106
# r     25

# %%
mpg['drv'].value_counts()
# Out:
# f    106
# 4    103
# r     25
# Name: drv, dtype: int64

# %%
mpg['drv'].value_counts()\ #빈도
.to_frame('n')\ #변수명 n으로 바ㅆ꾸기
.rename_axis('drv')\ #axis에 drv 지정
.query('n>100')  #n이 100을 초과한 경우
# Out:
#        n
# drv
# f    106
# 4    103

# %%
test1=pd.DataFrame({'id' : [1,2,3,4,5],
                   'midterm' : [60,80,70,90,85]})
test2=pd.DataFrame({'id' : [1,2,3,4,5],
                   'final' : [70,83,65,95,80]})

# %%
test1
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85

# %%
test2
# Out:
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   4     95
# 4   5     80

# %%
total=pd.merge(test1,test2,how='left',on='id')
total
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65
# 3   4       90     95
# 4   5       85     80

# %%
name=pd.DataFrame({'nclass':[1,2,3,4,5],
                  'teacher': ["kim",'lee','park','choi','jung']})

# %%
name
# Out:
#    nclass teacher
# 0       1     kim
# 1       2     lee
# 2       3    park
# 3       4    choi
# 4       5    jung

# %%
exam_new=pd.merge(exam,name,how='left',on='nclass')
exam_new
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50     kim
# 1    2       1    60       97       60     kim
# 2    3       1    45       86       78     kim
# 3    4       1    30       98       58     kim
# 4    5       2    25       80       65     lee
# 5    6       2    50       89       98     lee
# 6    7       2    80       90       45     lee
# 7    8       2    90       78       25     lee
# 8    9       3    20       98       15    park
# 9   10       3    50       98       45    park
# 10  11       3    65       65       65    park
# 11  12       3    45       85       32    park
# 12  13       4    46       98       65    choi
# 13  14       4    48       87       12    choi
# 14  15       4    75       56       78    choi
# 15  16       4    58       98       65    choi
# 16  17       5    65       68       98    jung
# 17  18       5    80       78       90    jung
# 18  19       5    89       68       87    jung
# 19  20       5    78       83       58    jung

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame({'sex':['M','F',np.nan,'M','F'],
                'score':[5,4,3,4,np.nan]})
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df['score']+1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# 4    NaN
# Name: score, dtype: float64

# %%
pd.isna(df)
# Out:
#      sex  score
# 0  False  False
# 1  False  False
# 2   True  False
# 3  False  False
# 4  False   True

# %%
pd.isna(df).sum()
# Out:
# sex      1
# score    1
# dtype: int64

# %%
df.dropna(subset=['score'])
df
# Out:
#    sex  score
# 0    M    5.0
# 1    F    4.0
# 2  NaN    3.0
# 3    M    4.0
# 4    F    NaN

# %%
df_nomiss=df.dropna(subset=['score'])
df_nomiss['score']+1
# Out:
# 0    6.0
# 1    5.0
# 2    4.0
# 3    5.0
# Name: score, dtype: float64

# %%
df_nomiss=df.dropna(subset=['score','sex'])
df_nomiss
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
df_nomiss2=df.dropna()
df_nomiss2
# Out:
#   sex  score
# 0   M    5.0
# 1   F    4.0
# 3   M    4.0

# %%
exam=pd.read_csv('exam.csv')
exam.loc[[2,7,14],['math']]=np.nan
exam
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1  50.0       98       50
# 1            1   2      1  60.0       97       60
# 2            2   3      1   NaN       86       78
# 3            3   4      1  30.0       98       58
# 4            4   5      2  25.0       80       65
# 5            5   6      2  50.0       89       98
# 6            6   7      2  80.0       90       45
# 7            7   8      2   NaN       78       25
# 8            8   9      3  20.0       98       15
# 9            9  10      3  50.0       98       45
# 10          10  11      3  65.0       65       65
# 11          11  12      3  45.0       85       32
# 12          12  13      4  46.0       98       65
# 13          13  14      4  48.0       87       12
# 14          14  15      4   NaN       56       78
# 15          15  16      4  58.0       98       65
# 16          16  17      5  65.0       68       98
# 17          17  18      5  80.0       78       90
# 18          18  19      5  89.0       68       87
# 19          19  20      5  78.0       83       58

# %%
exam['math'].mean()
# Out:
# 55.23529411764706

# %%
exam['math']=exam['math'].fillna(55)
exam
# Out:
#     Unnamed: 0  id  class  math  english  science
# 0            0   1      1  50.0       98       50
# 1            1   2      1  60.0       97       60
# 2            2   3      1  55.0       86       78
# 3            3   4      1  30.0       98       58
# 4            4   5      2  25.0       80       65
# 5            5   6      2  50.0       89       98
# 6            6   7      2  80.0       90       45
# 7            7   8      2  55.0       78       25
# 8            8   9      3  20.0       98       15
# 9            9  10      3  50.0       98       45
# 10          10  11      3  65.0       65       65
# 11          11  12      3  45.0       85       32
# 12          12  13      4  46.0       98       65
# 13          13  14      4  48.0       87       12
# 14          14  15      4  55.0       56       78
# 15          15  16      4  58.0       98       65
# 16          16  17      5  65.0       68       98
# 17          17  18      5  80.0       78       90
# 18          18  19      5  89.0       68       87
# 19          19  20      5  78.0       83       58

# %%
mpg=pd.read_csv('mpg.csv')

# %%
import seaborn as sns
sns.boxplot(data=mpg,y='hwy')
# Out:
# <AxesSubplot:ylabel='hwy'>

# %%
pct25=mpg['hwy'].quantile(.25)
pct25
# Out:
# 18.0

# %%
mpg['hwy']=np.where((mpg['hwy']<4.5)|(mpg['hwy']>40.5),
                   np.nan,mpg['hwy'])
mpg['hwy'].isna().sum()
# Out:
# 3

# %%
mpg.dropna(subset=['hwy'])\
.groupby('drv')\
.agg(mean_hwy='hwy','mean'))
# Out:
#   Input In [351]
#     .agg(mean_hwy='hwy','mean'))
#                               ^
# SyntaxError: positional argument follows keyword argument
