# %%
object
groupby
sort_values()
sort_index()

# %%
import pandas as pd

# %%
df=pd.read_csv("https://raw.githubusercontent.com/sidsriv/Introduction-to-Data-Science-in-python/master/mpg.csv")

# %%
df
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
df=df.iloc[:,1:]  #Unnamed: 0제거하기
#df.drop(['Unnamed: 0'],axis = 1, inplace=True)

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
df.groupby(['manufacturer', 'class'])

# %%
df.groupby(['manufacturer', 'class']).mean()[['hwy']]
# Out:
#                                hwy
# manufacturer class
# audi         compact     26.933333
#              midsize     24.000000
# chevrolet    2seater     24.800000
#              midsize     27.600000
#              suv         17.111111
# dodge        minivan     22.363636
#              pickup      16.105263
#              suv         16.000000
# ford         pickup      16.428571
#              subcompact  23.222222
#              suv         17.777778
# honda        subcompact  32.555556
# hyundai      midsize     27.714286
#              subcompact  26.000000
# jeep         suv         17.625000
# land rover   suv         16.500000
# lincoln      suv         17.000000
# mercury      suv         18.000000
# nissan       compact     28.000000
#              midsize     27.428571
#              suv         18.000000
# pontiac      midsize     26.400000
# subaru       compact     26.000000
#              subcompact  26.000000
#              suv         25.000000
# ...

# %%
mpg=df.rename({'class':'nclass'},axis=1)
mpg.query('nclass in ["compact","midsize","suv"]')
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#       nclass
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
mpg.query('nclass == "compact"'or 'nclass == "midsize"' or 'nclass == "suv"')
# Out:
#     manufacturer         model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi            a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi            a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi            a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi            a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi            a4    2.8  1999    6    auto(l5)   f   16   26  p
# 5           audi            a4    2.8  1999    6  manual(m5)   f   18   26  p
# 6           audi            a4    3.1  2008    6    auto(av)   f   18   27  p
# 7           audi    a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p
# 8           audi    a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p
# 9           audi    a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p
# 10          audi    a4 quattro    2.0  2008    4    auto(s6)   4   19   27  p
# ...

# %%
mpg[(mpg['class']=='compact')|(mpg['class']=='midsize')|(mpg['class']=='suv')]

cond1=mpg['class']=='compact'
cond2=mpg['class']=='midsize'
cond3=mpg['class']=='suv'

mpg[cond1|cond2|cond3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'class'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
#manufacturer별로 그룹을 만들고 그룹별 hwy의 평균을 구해리
df.groupby(['manufacturer','class']).agg(mean_hwy=('hwy', 'mean'))
# Out:
#                           mean_hwy
# manufacturer class
# audi         compact     26.933333
#              midsize     24.000000
# chevrolet    2seater     24.800000
#              midsize     27.600000
#              suv         17.111111
# dodge        minivan     22.363636
#              pickup      16.105263
#              suv         16.000000
# ford         pickup      16.428571
#              subcompact  23.222222
#              suv         17.777778
# honda        subcompact  32.555556
# hyundai      midsize     27.714286
#              subcompact  26.000000
# jeep         suv         17.625000
# land rover   suv         16.500000
# lincoln      suv         17.000000
# mercury      suv         18.000000
# nissan       compact     28.000000
#              midsize     27.428571
#              suv         18.000000
# pontiac      midsize     26.400000
# subaru       compact     26.000000
#              subcompact  26.000000
#              suv         25.000000
# ...

# %%
groupby(class=='compact','midsize','suv').mean()
# Out:
#   Input In [54]
#     groupby(class=='compact','midsize','suv').mean()
#             ^
# SyntaxError: invalid syntax

# %%
df.query('nclass == "compact"'or 'nclass == "midsize"' or 'nclass == "suv"') 
df=df.rename({'class':'nclass'},axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\computation\scope.py:195, in Scope.resolve(self, key, is_local)
#     194 if self.has_resolvers:
# --> 195     return self.resolvers[key]
#     197 # if we're here that means that we have no locals and we also have
#     198 # no resolvers
#
# File ~\anaconda3\lib\collections\__init__.py:941, in ChainMap.__getitem__(self, key)
#     940         pass
# --> 941 return self.__missing__(key)
#
# File ~\anaconda3\lib\collections\__init__.py:933, in ChainMap.__missing__(self, key)
#     932 def __missing__(self, key):
# --> 933     raise KeyError(key)
#
# KeyError: 'nclass'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
import numpy as np

# %%
df.loc[:,'cty']
df['cty']  #문자면 디폴트가 칼럼
df[:2]    #숫자면 디폴트가 로우
df.cty
df['cty'].mean()
np.mean(df['cty'])
df.mean()
df.apply('mean')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_284\3438347453.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# C:\Users\user\AppData\Local\Temp\ipykernel_284\3438347453.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.apply('mean')
# displ       3.471795
# year     2003.500000
# cyl         5.888889
# cty        16.858974
# hwy        23.440171
# dtype: float64

# %%
df.drv.unique()
# Out:
# array(['f', '4', 'r'], dtype=object)

# %%
df['cty'].apply(np.sum)
# Out:
# 0      18
# 1      21
# 2      20
# 3      21
# 4      16
#        ..
# 229    19
# 230    21
# 231    16
# 232    18
# 233    17
# Name: cty, Length: 234, dtype: int32

# %%
df=mpg.copy()
pd.isna(df)
# Out:
#      manufacturer  model  displ   year    cyl  trans    drv    cty    hwy  \
# 0           False  False  False  False  False  False  False  False  False
# 1           False  False  False  False  False  False  False  False  False
# 2           False  False  False  False  False  False  False  False  False
# 3           False  False  False  False  False  False  False  False  False
# 4           False  False  False  False  False  False  False  False  False
# ..            ...    ...    ...    ...    ...    ...    ...    ...    ...
# 229         False  False  False  False  False  False  False  False  False
# 230         False  False  False  False  False  False  False  False  False
# 231         False  False  False  False  False  False  False  False  False
# 232         False  False  False  False  False  False  False  False  False
# 233         False  False  False  False  False  False  False  False  False
#
#         fl  nclass
# 0    False   False
# 1    False   False
# ...

# %%
mpg['drv'] = np.where(mpg['drv'] == 'r', np.nan, mpg['drv'])
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#       nclass
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...
