# %% [markdown]
# # 맛집

# %% [markdown]
# ## 필요 라이브러리

# %%
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
from urllib.request import urlopen, urlretrieve
from urllib.parse import quote_plus
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
import os
os.getcwd()
os.chdir('C:\\Users\\user')

# %%
driver = webdriver.Chrome('chromedriver.exe')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7252\530843676.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %% [markdown]
# ## 맛집 찾기

# %%
url = "https://www.google.com/maps"
driver.get(url)

# %%
location = input('위치를 영어로 입력하세요: ')
xpath = '/html/body/div[3]/div[9]/div[3]/div[1]/div[1]/div[1]/div[2]/form/div[2]/div[3]/div/input[1]'
search = driver.find_element(By.XPATH, xpath)
search.clear()
search.send_keys(f'{location} restaurant')
search.send_keys(Keys.ENTER)
# Out:
# 위치를 영어로 입력하세요:  gangnam

# %% [markdown]
# ## 식당 이름 따기

# %%
import datetime
import time

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        scroll = driver.find_element(By.XPATH, '/html/body/div[3]/div[9]/div[9]/div/div/div[1]/div[2]/div/div[1]/div/div/div[2]/div[1]')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scroll)
        time.sleep(1)
        if datetime.datetime.now() > end:
            break

# %%
doScrollDown(5)

# %%
rec = driver.find_elements(By.CLASS_NAME, 'NrDZNb')

lists = []
for i in range(0, len(rec)):
    lists.append(rec[i].text)

lists
# Out:
# ['강남면옥',
#  '브릭오븐 강남점',
#  '강가 역삼점 Ganga',
#  '케르반',
#  '오스틴(Austin) 강남역점',
#  '쉐이크쉑 강남점',
#  '갓덴스시 강남점',
#  '강남 돼지상회 무한리필',
#  '강남교자 본점',
#  'Gangnam Myun Oak (Galbi Jjim)',
#  '강남식당',
#  '마녀주방 강남점',
#  'After Work BBQ',
#  '장모님이떴다 본점',
#  '노란상 소갈비 강남구청점',
#  '정돈 강남점',
#  '바비레드 강남본점',
#  '전우소고기해장국',
#  '무쏘 강남역점',
#  '메이드',
#  '능라도 강남점',
#  '강남삼겹살',
#  '에이스크랩 강남직영점',
#  '빌즈 강남']

# %%
locat_li = []
for i in range(0, len(lists)):
    locat_li.append(lists[i]+','+' '+location)

locat_li
# Out:
# ['강남면옥, gangnam',
#  '브릭오븐 강남점, gangnam',
#  '강가 역삼점 Ganga, gangnam',
#  '케르반, gangnam',
#  '오스틴(Austin) 강남역점, gangnam',
#  '쉐이크쉑 강남점, gangnam',
#  '갓덴스시 강남점, gangnam',
#  '강남 돼지상회 무한리필, gangnam',
#  '강남교자 본점, gangnam',
#  'Gangnam Myun Oak (Galbi Jjim), gangnam',
#  '강남식당, gangnam',
#  '마녀주방 강남점, gangnam',
#  'After Work BBQ, gangnam',
#  '장모님이떴다 본점, gangnam',
#  '노란상 소갈비 강남구청점, gangnam',
#  '정돈 강남점, gangnam',
#  '바비레드 강남본점, gangnam',
#  '전우소고기해장국, gangnam',
#  '무쏘 강남역점, gangnam',
#  '메이드, gangnam',
#  '능라도 강남점, gangnam',
#  '강남삼겹살, gangnam',
#  '에이스크랩 강남직영점, gangnam',
#  '빌즈 강남, gangnam']

# %%
len(lists)
# Out:
# 24

# %% [markdown]
# ## 별점 따기

# %%
rec = driver.find_elements(By.CLASS_NAME, 'AJB7ye')

reviews = []
for i in range(0, len(rec)):
    if rec[i] == '리뷰 없음':
        rec[i] = 0
    else:
        reviews.append(rec[i].text)


reviews
# Out:
# ['4.1(1,095) · ₩₩',
#  '4.1(1,061) · ₩₩',
#  '3.8(215)',
#  '3.9(326) · ₩₩',
#  '3.9(445)',
#  '3.9(7,094) · ₩₩₩',
#  '4.2(1,805) · ₩₩₩',
#  '3.8(825) · ₩₩',
#  '3.9(712) · ₩₩',
#  '5.0(2)',
#  '리뷰 없음',
#  '4.1(659)',
#  '3.7(3)',
#  '3.7(3)',
#  '4.3(330) · ₩₩',
#  '4.5(926) · ₩₩₩',
#  '4.3(920) · ₩₩',
#  '4.4(27)',
#  '3.3(211)',
#  '3.7(133)',
#  '4.1(1,426) · ₩₩₩',
#  '4.0(4)',
#  '4.1(33)',
#  '4.0(505) · ₩₩₩']

# %%
rvs = []
for i in range(0, len(reviews)):
    rvs.append(reviews[i][:3])
    
rvs
# Out:
# ['4.1',
#  '4.1',
#  '3.8',
#  '3.9',
#  '3.9',
#  '3.9',
#  '4.2',
#  '3.8',
#  '3.9',
#  '5.0',
#  '리뷰 ',
#  '4.1',
#  '3.7',
#  '3.7',
#  '4.3',
#  '4.5',
#  '4.3',
#  '4.4',
#  '3.3',
#  '3.7',
#  '4.1',
#  '4.0',
#  '4.1',
#  '4.0']

# %%
len(rvs)
# Out:
# 24

# %% [markdown]
# ## 음식 종류

# %%
rec = driver.find_elements(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t > div > div > div.bfdHYd.Ppzolf.OFBs3e > div.lI9IFe > div.y7PRA > div > div > div.UaQhfb.fontBodyMedium > div > div:nth-child(2) > span:nth-child(1) > jsl > span:nth-child(2)')

food = []
for i in range(0, len(rec)):
    food.append(rec[i].text)

food
# Out:
# ['한식',
#  '피자',
#  '인도 요리',
#  '터키 요리',
#  '미국 요리',
#  '햄버거',
#  '초밥',
#  '한국식 BBQ',
#  '국수 전문점',
#  '음식점',
#  '한식',
#  '이탈리아 요리',
#  '바베큐',
#  '한식',
#  '한국식 BBQ',
#  '돈까스 전문식당',
#  '퓨전 음식점',
#  '한식',
#  '한국식 BBQ',
#  '현대식 미국 요리',
#  '냉면 전문점',
#  '한국식 BBQ',
#  '음식점',
#  '호주 요리']

# %%
len(food)
# Out:
# 24

# %% [markdown]
# ## 영업중

# %%
rec = driver.find_elements(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div > div > div.bfdHYd.Ppzolf.OFBs3e > div.lI9IFe > div.y7PRA > div > div > div.UaQhfb.fontBodyMedium > div > div > span > jsl > span > span:nth-child(2)')

opens = []
for i in range(0, len(rec)):
    opens.append(rec[i].text)

opens
# Out:
# ['⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 11:00에 영업 종료',
#  '⋅ 오후 2:30에 영업 종료 ⋅ 오후 5:00에 영업 재개',
#  '⋅ 오후 9:00에 영업 종료',
#  '⋅ 오후 3:00에 영업 종료 ⋅ 오후 5:00에 영업 재개',
#  '⋅ 오후 11:00에 영업 종료',
#  '⋅ 오후 9:30에 영업 종료',
#  '⋅ 오전 12:00에 영업 종료',
#  '⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 3:00에 영업 종료 ⋅ 오후 5:00에 영업 재개',
#  '⋅ 오후 10:30에 영업 종료',
#  '⋅ 오후 9:00에 영업 종료',
#  '⋅ 오후 2:00에 영업 종료 ⋅ 오후 5:00에 영업 재개',
#  '⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 9:00에 영업 종료',
#  '⋅ 오후 9:00에 영업 종료',
#  '⋅ 오후 9:30에 영업 종료',
#  '⋅ 오후 11:30에 영업 종료',
#  '⋅ 오후 10:00에 영업 종료',
#  '⋅ 오후 10:00에 영업 종료']

# %%
len(opens)
# Out:
# 22

# %% [markdown]
# ## 영업상태

# %%
rec = driver.find_elements(By.CSS_SELECTOR, 
                           '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd.QjC7t > div > div > div.bfdHYd.Ppzolf.OFBs3e > div.lI9IFe > div.y7PRA > div > div > div.UaQhfb.fontBodyMedium > div > div > span > jsl > span > span:nth-child(1)')

now = []
for i in range(0, 50):
    now.append(rec[i].text)

now
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [172], in <cell line: 5>()
#       4 now = []
#       5 for i in range(0, 50):
# ----> 6     now.append(rec[i].text)
#       8 now
#
# IndexError: list index out of range

# %% [markdown]
# ## 영업 시간

# %%
rec = driver.find_elements(By.CSS_SELECTOR, '#QA0Szd > div > div > div.w6VYqd > div.bJzME.tTVLSc > div > div.e07Vkf.kA9KIf > div > div > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div.m6QErb.DxyBCb.kA9KIf.dS8AEf.ecceSd > div > div > div.bfdHYd.Ppzolf.OFBs3e > div.lI9IFe > div.y7PRA > div > div > div.UaQhfb.fontBodyMedium > div > div > span > jsl > span > span:nth-child(2)')

opens = []
for i in range(0, 50):
    opens.append(rec[i].text)

opens
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [149], in <cell line: 4>()
#       3 opens = []
#       4 for i in range(0, 50):
# ----> 5     opens.append(rec[i].text)
#       7 opens
#
# IndexError: list index out of range

# %%
len(opens)
# Out:
# 22

# %% [markdown]
# ## 데이터프레임 만들기

# %%
import pandas as pd

df = pd.DataFrame(zip(lists, rvs, food, now, opens), columns=['name', 'reviews', 'type', 'now', 'hours'])
df
# Out:
#                              name reviews       type      now  \
# 0                            강남면옥     4.1         한식     영업 중
# 1                        브릭오븐 강남점     4.1         피자     영업 중
# 2                    강가 역삼점 Ganga     3.8      인도 요리     영업 중
# 3                             케르반     3.9      터키 요리     영업 중
# 4                오스틴(Austin) 강남역점     3.9      미국 요리     영업 중
# 5                        쉐이크쉑 강남점     3.9        햄버거     영업 중
# 6                        갓덴스시 강남점     4.2         초밥     영업 중
# 7                    강남 돼지상회 무한리필     3.8    한국식 BBQ     영업 중
# 8                         강남교자 본점     3.9     국수 전문점     영업 중
# 9   Gangnam Myun Oak (Galbi Jjim)     5.0        음식점     영업 중
# 10                           강남식당     리뷰          한식     영업 중
# 11                       마녀주방 강남점     4.1    이탈리아 요리     영업 중
# 12                 After Work BBQ     3.7        바베큐     영업 중
# 13                      장모님이떴다 본점     3.7         한식  24시간 영업
# 14                  노란상 소갈비 강남구청점     4.3    한국식 BBQ     영업 중
# 15                         정돈 강남점     4.5   돈까스 전문식당     영업 중
# 16                      바비레드 강남본점     4.3     퓨전 음식점     영업 중
# 17                       전우소고기해장국     4.4         한식     영업 중
# 18                        무쏘 강남역점     3.3    한국식 BBQ  24시간 영업
# 19                            메이드     3.7  현대식 미국 요리     영업 중
# 20                        능라도 강남점     4.1     냉면 전문점     영업 중
# 21                          강남삼겹살     4.0    한국식 BBQ     영업 중
#
#                                 hours
# 0                   ⋅ 오후 10:00에 영업 종료
# 1                   ⋅ 오후 11:00에 영업 종료
# 2   ⋅ 오후 2:30에 영업 종료 ⋅ 오후 5:00에 영업 재개
# 3                    ⋅ 오후 9:00에 영업 종료
# 4   ⋅ 오후 3:00에 영업 종료 ⋅ 오후 5:00에 영업 재개
# 5                   ⋅ 오후 11:00에 영업 종료
# 6                    ⋅ 오후 9:30에 영업 종료
# 7                   ⋅ 오전 12:00에 영업 종료
# 8                   ⋅ 오후 10:00에 영업 종료
# 9                   ⋅ 오후 10:00에 영업 종료
# 10                  ⋅ 오후 10:00에 영업 종료
# 11  ⋅ 오후 3:00에 영업 종료 ⋅ 오후 5:00에 영업 재개
# 12                  ⋅ 오후 10:30에 영업 종료
# 13                   ⋅ 오후 9:00에 영업 종료
# 14  ⋅ 오후 2:00에 영업 종료 ⋅ 오후 5:00에 영업 재개
# 15                  ⋅ 오후 10:00에 영업 종료
# 16                   ⋅ 오후 9:00에 영업 종료
# 17                   ⋅ 오후 9:00에 영업 종료
# 18                   ⋅ 오후 9:30에 영업 종료
# 19                  ⋅ 오후 11:30에 영업 종료
# 20                  ⋅ 오후 10:00에 영업 종료
# 21                  ⋅ 오후 10:00에 영업 종료

# %%
doScrollDown(15)

# %%
url = driver.current_url
resp = requests.get(url)

e = driver.find_elements(By.CLASS_NAME, 'hfpxzc')

c = []
for i in range(0, 50):
    e[i].send_keys(Keys.RETURN)
    url = driver.current_url
    c.append(url)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [175], in <cell line: 7>()
#       6 c = []
#       7 for i in range(0, 50):
# ----> 8     e[i].send_keys(Keys.RETURN)
#       9     url = driver.current_url
#      10     c.append(url)
#
# IndexError: list index out of range

# %% [markdown]
# # 링크 따기

# %%
url = "https://www.google.com/maps"
driver.get(url)

# %%
xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
search = driver.find_element(By.XPATH, xpath)
search.clear()
search.send_keys(f'{location} restaurant')
search.send_keys(Keys.ENTER)
driver.implicitly_wait(10)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [186], in <cell line: 2>()
#       1 xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
# ----> 2 search = driver.find_element(By.XPATH, xpath)
#       3 search.clear()
#       4 search.send_keys(f'{location} restaurant')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008EACD3+2075859]
# 	Ordinal0 [0x0087EE61+1633889]
# 	Ordinal0 [0x0077B7BD+571325]
# 	Ordinal0 [0x007AAC2F+764975]
# 	Ordinal0 [0x007AAE1B+765467]
# 	Ordinal0 [0x007DD0F2+970994]
# 	Ordinal0 [0x007C7364+881508]
# 	Ordinal0 [0x007DB56A+963946]
# 	Ordinal0 [0x007C7136+880950]
# 	Ordinal0 [0x0079FEFD+720637]
# 	Ordinal0 [0x007A0F3F+724799]
# 	GetHandleVerifier [0x00B9EED2+2769538]
# 	GetHandleVerifier [0x00B90D95+2711877]
# 	GetHandleVerifier [0x0097A03A+521194]
# 	GetHandleVerifier [0x00978DA0+516432]
# 	Ordinal0 [0x0088682C+1665068]
# 	Ordinal0 [0x0088B128+1683752]
# 	Ordinal0 [0x0088B215+1683989]
# 	Ordinal0 [0x00896484+1729668]
# 	BaseThreadInitThunk [0x75E8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A4E+238]

# %%
xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
search = driver.find_element(By.XPATH, xpath)
search.clear()
search.send_keys(f'{location} restaurant')
search.send_keys(Keys.ENTER)
driver.implicitly_wait(5)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [191], in <cell line: 2>()
#       1 xpath = '/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input'
# ----> 2 search = driver.find_element(By.XPATH, xpath)
#       3 search.clear()
#       4 search.send_keys(f'{location} restaurant')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     853     by = By.CSS_SELECTOR
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#     432     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     241         alert_text = value['alert'].get('text')
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/app/layout/div[3]/div[2]/shrinkable-layout/div/app-base/search-input-box/div/div/div/input"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008EACD3+2075859]
# 	Ordinal0 [0x0087EE61+1633889]
# 	Ordinal0 [0x0077B7BD+571325]
# 	Ordinal0 [0x007AAC2F+764975]
# 	Ordinal0 [0x007AAE1B+765467]
# 	Ordinal0 [0x007DD0F2+970994]
# 	Ordinal0 [0x007C7364+881508]
# 	Ordinal0 [0x007DB56A+963946]
# 	Ordinal0 [0x007C7136+880950]
# 	Ordinal0 [0x0079FEFD+720637]
# 	Ordinal0 [0x007A0F3F+724799]
# 	GetHandleVerifier [0x00B9EED2+2769538]
# 	GetHandleVerifier [0x00B90D95+2711877]
# 	GetHandleVerifier [0x0097A03A+521194]
# 	GetHandleVerifier [0x00978DA0+516432]
# 	Ordinal0 [0x0088682C+1665068]
# 	Ordinal0 [0x0088B128+1683752]
# 	Ordinal0 [0x0088B215+1683989]
# 	Ordinal0 [0x00896484+1729668]
# 	BaseThreadInitThunk [0x75E8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A4E+238]

# %%
driver.switch_to.frame('searchIframe')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py:87, in SwitchTo.frame(self, frame_reference)
#      86 try:
# ---> 87     frame_reference = self._driver.find_element(By.ID, frame_reference)
#      88 except NoSuchElementException:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[id="searchIframe"]"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008EACD3+2075859]
# 	Ordinal0 [0x0087EE61+1633889]
# 	Ordinal0 [0x0077B7BD+571325]
# 	Ordinal0 [0x007AAC2F+764975]
# 	Ordinal0 [0x007AAE1B+765467]
# 	Ordinal0 [0x007DD0F2+970994]
# 	Ordinal0 [0x007C7364+881508]
# 	Ordinal0 [0x007DB56A+963946]
# 	Ordinal0 [0x007C7136+880950]
# 	Ordinal0 [0x0079FEFD+720637]
# 	Ordinal0 [0x007A0F3F+724799]
# 	GetHandleVerifier [0x00B9EED2+2769538]
# 	GetHandleVerifier [0x00B90D95+2711877]
# 	GetHandleVerifier [0x0097A03A+521194]
# 	GetHandleVerifier [0x00978DA0+516432]
# 	Ordinal0 [0x0088682C+1665068]
# 	Ordinal0 [0x0088B128+1683752]
# 	Ordinal0 [0x0088B215+1683989]
# 	Ordinal0 [0x00896484+1729668]
# 	BaseThreadInitThunk [0x75E8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A4E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchElementException                    Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py:90, in SwitchTo.frame(self, frame_reference)
#      89 try:
# ---> 90     frame_reference = self._driver.find_element(By.NAME, frame_reference)
#      91 except NoSuchElementException:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:856, in WebDriver.find_element(self, by, value)
#     854     value = '[name="%s"]' % value
# --> 856 return self.execute(Command.FIND_ELEMENT, {
#     857     'using': by,
#     858     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response['value'] = self._unwrap_value(
#     431         response.get('value', None))
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:243, in ErrorHandler.check_response(self, response)
#     242     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 243 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"[name="searchIframe"]"}
#   (Session info: chrome=107.0.5304.88)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x008EACD3+2075859]
# 	Ordinal0 [0x0087EE61+1633889]
# 	Ordinal0 [0x0077B7BD+571325]
# 	Ordinal0 [0x007AAC2F+764975]
# 	Ordinal0 [0x007AAE1B+765467]
# 	Ordinal0 [0x007DD0F2+970994]
# 	Ordinal0 [0x007C7364+881508]
# 	Ordinal0 [0x007DB56A+963946]
# 	Ordinal0 [0x007C7136+880950]
# 	Ordinal0 [0x0079FEFD+720637]
# 	Ordinal0 [0x007A0F3F+724799]
# 	GetHandleVerifier [0x00B9EED2+2769538]
# 	GetHandleVerifier [0x00B90D95+2711877]
# 	GetHandleVerifier [0x0097A03A+521194]
# 	GetHandleVerifier [0x00978DA0+516432]
# 	Ordinal0 [0x0088682C+1665068]
# 	Ordinal0 [0x0088B128+1683752]
# 	Ordinal0 [0x0088B215+1683989]
# 	Ordinal0 [0x00896484+1729668]
# 	BaseThreadInitThunk [0x75E8FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A7E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F47A4E+238]
#
#
# During handling of the above exception, another exception occurred:
#
# NoSuchFrameException                      Traceback (most recent call last)
# Input In [179], in <cell line: 1>()
# ----> 1 driver.switch_to.frame('searchIframe')
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\switch_to.py:92, in SwitchTo.frame(self, frame_reference)
#      90             frame_reference = self._driver.find_element(By.NAME, frame_reference)
#      91         except NoSuchElementException:
# ---> 92             raise NoSuchFrameException(frame_reference)
#      94 self._driver.execute(Command.SWITCH_TO_FRAME, {'id': frame_reference})
#
# NoSuchFrameException: Message: searchIframe

# %%
import datetime
import time

def doScrollDown(whileSeconds):
    start = datetime.datetime.now()
    end = start + datetime.timedelta(seconds=whileSeconds)
    while True:
        scroll = driver.find_element(By.XPATH, '/html/body/div[3]/div/div[2]/div[1]')
        driver.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scroll)
        time.sleep(1)
        if datetime.datetime.now() > end:
            break

# %%
doScrollDown(5)

# %%
url = driver.current_url
resp = requests.get(url)

e = driver.find_elements(By.CLASS_NAME, 'place_bluelink.TYaxT')

c = []
for i in range(2, 22):
    e[i].click()
    url = driver.current_url
    c.append(url)
    
d = []
for i in range(24, 54):
    e[i].click()
    url = driver.current_url
    d.append(url)

# %%
x = c+d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [146], in <cell line: 1>()
# ----> 1 x = c+d
#
# NameError: name 'd' is not defined

# %%
len(x)
# Out:
# 50

# %%
# driver.close()

# %%
food_place['link'] = x

# %%
food_place[:3]
# Out:
#      식당이름                  위도                  경도    별점  \
# 0     카미야  37.552582876796265   126.9223637900431  4.48
# 1  스미비부타동    37.5493446009239    126.922229088687  4.46
# 2  스케줄 합정  37.549127753591826  126.91607773123069  4.39
#
#                                                   리뷰  \
# 0  ["음식이 맛있어요", "가성비가 좋아요", "양이 많아요", "친절해요", "혼밥...
# 1  ["음식이 맛있어요", "혼밥하기 좋아요", "친절해요", "양이 많아요", "재료...
# 2  ["음식이 맛있어요", "인테리어가 멋져요", "친절해요", "특별한 날 가기 좋아...
#
#                                                 link
# 0  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 1  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 2  https://map.naver.com/v5/search/%ED%99%8D%EB%8...

# %% [markdown]
# ## 위치 포함한 탑10

# %%
food_place.sort_values(by=['별점'], ascending=False, inplace=True)
food_place.reset_index(drop=True, inplace=True)
food_place[:3]
# Out:
#        식당이름                위도                경도    별점  \
# 0       썬키친  37.5486490595911  126.916979045786  4.89
# 1  야키토리 나루토  37.5493540644272  126.920207967712  4.89
# 2      에그써티  37.5606091272674  126.925418144268  4.85
#
#                                                   리뷰  \
# 0  ["음식이 맛있어요", "특별한 메뉴가 있어요", "친절해요", "인테리어가 멋져요...
# 1  ["음식이 맛있어요", "친절해요", "특별한 메뉴가 있어요", "재료가 신선해요"...
# 2  ["음식이 맛있어요", "친절해요", "재료가 신선해요", "특별한 메뉴가 있어요"...
#
#                                                 link
# 0  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 1  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 2  https://map.naver.com/v5/search/%ED%99%8D%EB%8...

# %%
upper = food_place.iloc[:10, :]
upper
# Out:
#               식당이름                  위도                  경도    별점  \
# 0              썬키친    37.5486490595911    126.916979045786  4.89
# 1         야키토리 나루토    37.5493540644272    126.920207967712  4.89
# 2             에그써티    37.5606091272674    126.925418144268  4.85
# 3           필로베이커리    37.5555557347446    126.924472523465  4.78
# 4               육지  37.549687345281505  126.91745771217005  4.78
# 5               컴피    37.5488663918405     126.91597617722  4.75
# 6           산더미불고기    37.5494264051392    126.920594912252  4.67
# 7           모센즈스위트    37.5498067386666    126.920761992685  4.66
# 8       하이디라오 홍대지점    37.5571921297692    126.924760602353  4.61
# 9  또보겠지떡볶이집 붕붕허니비점  37.558945244782436  126.92440798585419  4.58
#
#                                                   리뷰  \
# 0  ["음식이 맛있어요", "특별한 메뉴가 있어요", "친절해요", "인테리어가 멋져요...
# 1  ["음식이 맛있어요", "친절해요", "특별한 메뉴가 있어요", "재료가 신선해요"...
# 2  ["음식이 맛있어요", "친절해요", "재료가 신선해요", "특별한 메뉴가 있어요"...
# 3  ["특별한 메뉴가 있어요", "디저트가 맛있어요", "인테리어가 멋져요", "음료가...
# 4  ["음식이 맛있어요", "친절해요", "재료가 신선해요", "특별한 메뉴가 있어요"...
# 5  ["음악이 좋아요", "친절해요", "인테리어가 멋져요", "음식이 맛있어요", "...
# 6  ["음식이 맛있어요", "양이 많아요", "가성비가 좋아요", "재료가 신선해요",...
# 7  ["디저트가 맛있어요", "특별한 메뉴가 있어요", "친절해요", "커피가 맛있어요...
# 8  ["음식이 맛있어요", "친절해요", "매장이 넓어요", "재료가 신선해요", "매...
# 9  ["음식이 맛있어요", "친절해요", "특별한 메뉴가 있어요", "가성비가 좋아요"...
#
#                                                 link
# 0  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 1  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 2  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 3  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 4  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 5  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 6  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 7  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 8  https://map.naver.com/v5/search/%ED%99%8D%EB%8...
# 9  https://map.naver.com/v5/search/%ED%99%8D%EB%8...

# %% [markdown]
# # 지도

# %% [markdown]
# ### from website

# %%
import requests
import pandas as pd
import numpy as np
import folium
from folium.plugins import MiniMap

# %%
locations = pd.read_csv('./project/geocode - Sheet2.csv')
locations
# Out:
#                                    resturants   Latitude  Longitude
# 0                        Chef Guo, new york',  40.756381 -73.971662
# 1                   Hawksmoor NYC, new york',  40.739536 -73.986388
# 2                           Niles, new york',  42.837568 -76.413546
# 3                       Crown Shy, new york',  40.706505 -74.007772
# 4              The Mercer Kitchen, new york',  40.724842 -73.998649
# 5                         5 냅킨 버거, new york',  40.760180 -73.991095
# 6               K.Rico Steakhouse, new york',  40.764356 -73.988027
# 7          Boucherie Union Square, new york',  40.737255 -73.988225
# 8                        noreetuh, new york',  40.727281 -73.985245
# 9                  Brooklyn Diner, new york',  40.756577 -73.985610
# 10                   Jean-Georges, new york',  40.769025 -73.981626
# 11                     The Modern, new york',  40.761081 -73.976753
# 12               Keens Steakhouse, new york',  40.750786 -73.986461
# 13                           Dame, new york',  40.728946 -74.001506
# 14                     San Pietro, new york',  40.760483 -73.974442
# 15                      Joe Allen, new york',  40.760141 -73.989071
# 16                Jane Restaurant, new york',  40.727368 -74.000246
# 17        "Ellen's Stardust Diner, new york",  40.761872 -73.983436
# 18  ICHIRAN Ramen NY Times Square, new york',  40.760058 -73.983325
# 19         COTE Korean Steakhouse, new york',  40.741046 -73.991421
# 20                         Per Se, new york',  40.768218 -73.982899
# 21                       "Raoul's, new york",  40.726182 -74.002131
# 22     San Carlo Osteria Piemonte, new york',  40.725186 -74.002232
# 23                         Club A, new york',  40.760051 -73.965573
# 24                 The Clocktower, new york',  40.741295 -73.987368
# 25                           SAGA, new york',  40.706505 -74.007772
# 26                        Jungsik, new york',  40.718827 -74.009075
# 27                           Orso, new york',  40.760012 -73.989010
# 28           Peak Restaurant & Bar, new york'  40.753996 -74.001073

# %%
def elec_location(region,page_num):
    url = 'https://dapi.kakao.com/v2/local/search/keyword.json'
    params = {'query': region,'page': page_num}
    headers = {"Authorization": "KakaoAK de2ab0f4e5f24304ac7898b7de2cacd8"}

    places = requests.get(url, params=params, headers=headers).json()['documents']
    total = requests.get(url, params=params, headers=headers).json()['meta']['total_count']
    return places

# %%
def elec_info(places):
    X = []
    Y = []
    stores = []
    road_address = []
    place_url = []
    ID = []
    for place in places:
        X.append(float(place['x']))
        Y.append(float(place['y']))
        stores.append(place['place_name'])
        road_address.append(place['road_address_name'])
        place_url.append(place['place_url'])
        ID.append(place['id'])

    ar = np.array([ID,stores, X, Y, road_address,place_url]).T
    df = pd.DataFrame(ar, columns = ['ID','stores', 'X', 'Y','road_address','place_url'])
    return df

# %%
def keywords(location_name):
    df = None
    for loca in location:
        for page in range(1,4):
            local_name = elec_location(loca, page)
            local_elec_info = elec_info(local_name)

            if df is None:
                df = local_elec_info
            elif local_elec_info is None:
                continue
            else:
                df = pd.concat([df, local_elec_info],join='outer', ignore_index = True)
    return df

# %%
def make_map(dfs):
    # 지도 생성하기
    m = folium.Map(location=locations.iloc[0][1:],   # 기준좌표: 서울시청
                   zoom_start=15)

    # 미니맵 추가하기
    minimap = MiniMap() 
    m.add_child(minimap)

    # 마커 추가하기
    for i in range(len(dfs)):
        # popup_text = f'''<a href={upper.iloc[i].link} target='_blank'>
        #             {upper.iloc[i]['식당이름']}</a> 별점: {upper.iloc[i]['별점']}<br>
        #             리뷰: {upper.iloc[i]['리뷰']}<br>'''

        #팝업 크기 조절
        # popup = folium.Popup(popup_text, min_width=100, max_width=300)
    
        # 마커 생성
        folium.Marker([locations['Latitude'][i],locations['Longitude'][i]],
                  tooltip=locations['resturants'][i],
                  # popup=popup, 
                      icon=folium.Icon(color='red', icon='info-sign')).add_to(m)
    return m

# %%
df = keywords(locations['resturants'])
df = df.drop_duplicates(['ID'])
df = df.reset_index()

make_map(locations)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d359bfac9a8f13b790706d59ec6ab39e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-minimap/3.6.1/Control.MiniMap.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d359bfac9a8f13b790706d59ec6ab39e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d359bfac9a8f13b790706d59ec6ab39e = L.map(
#                 &quot;map_d359bfac9a8f13b790706d59ec6ab39e&quot;,
#                 {
#                     center: [40.7563814, -73.971662],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_beecd1adcb1021fd3b5def52419d67f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d359bfac9a8f13b790706d59ec6ab39e);
#
#
#             var tile_layer_c5140fdb49056739c91c6814ec5f955e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#             var mini_map_4b3ba646a0e940520d1a0d17a4d9de99 = new L.Control.MiniMap(
#                 tile_layer_c5140fdb49056739c91c6814ec5f955e,
#                 {&quot;autoToggleDisplay&quot;: false, &quot;centerFixed&quot;: false, &quot;collapsedHeight&quot;: 25, &quot;collapsedWidth&quot;: 25, &quot;height&quot;: 150, &quot;minimized&quot;: false, &quot;position&quot;: &quot;bottomright&quot;, &quot;toggleDisplay&quot;: false, &quot;width&quot;: 150, &quot;zoomAnimation&quot;: false, &quot;zoomLevelOffset&quot;: -5}
#             );
#             map_d359bfac9a8f13b790706d59ec6ab39e.addControl(mini_map_4b3ba646a0e940520d1a0d17a4d9de99);
#
#
#             var marker_469327fb5adfb373ac1e3d125d382105 = L.marker(
#                 [40.7563814, -73.971662],
#                 {}
#             ).addTo(map_d359bfac9a8f13b790706d59ec6ab39e);
#
#
#             var icon_5012286e027a6c579070c36005bbbb29 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_469327fb5adfb373ac1e3d125d382105.setIcon(icon_5012286e027a6c579070c36005bbbb29);
#
#
#             marker_469327fb5adfb373ac1e3d125d382105.bindTooltip(
#                 `&lt;div&gt;
#                      Chef Guo, new york&#x27;,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_90f28d195bf4a0fe2360ae868769b157 = L.marker(
#                 [40.7395356, -73.9863884],
#                 {}
#             ).addTo(map_d359bfac9a8f13b790706d59ec6ab39e);
#
#
#             var icon_fb9516e39975e20ec68c735e65da6109 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_90f28d195bf4a0fe2360ae868769b157.setIcon(icon_fb9516e39975e20ec68c735e65da6109);
#
#
#             marker_90f28d195bf4a0fe2360ae868769b157.bindTooltip(
#                 `&lt;div&gt;
#                      Hawksmoor NYC, new york&#x27;,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d52f6a4fba820a9e553ff1a23cd5d6cd = L.marker(
#                 [42.8375683, -76.413546],
#                 {}
#             ).addTo(map_d359bfac9a8f13b790706d59ec6ab39e);
#
#
#             var icon_6dad9d9fa00cb07df12148ff0a69e575 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d52f6a4fba820a9e553ff1a23cd5d6cd.setIcon(icon_6dad9d9fa00cb07df12148ff0a69e575);
#
#
#             marker_d52f6a4fba820a9e553ff1a23cd5d6cd.bindTooltip(
#                 `&lt;div&gt;
#                      Niles, new york&#x27;,
#                  &lt;/div&gt;`,
#                 {&quot;sticky&
