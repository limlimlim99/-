# %%
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(data=df,x='sex')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
df.columns   #이름만 알고싶을 때
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.info()  #자세하게 알고싶을 때
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(data=df,x='class')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
sns.countplot(data=df,x='class',hue="alive")
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
df[['class','alive']]
# Out:
#       class alive
# 0     Third    no
# 1     First   yes
# 2     Third   yes
# 3     First   yes
# 4     Third    no
# ..      ...   ...
# 886  Second    no
# 887   First   yes
# 888   Third    no
# 889   First   yes
# 890   Third    no
#
# [891 rows x 2 columns]

# %%
sns.countplot(data=df,x='class',hue='alive')
# Out:
# <AxesSubplot:xlabel='class', ylabel='count'>

# %%
pip list|findstr py
# Out:
# astropy                       5.0.4
# brotlipy                      0.7.0
# daal4py                       2021.5.0
# debugpy                       1.5.1
# h5py                          3.6.0
# ipykernel                     6.9.1
# ipython                       8.2.0
# ipython-genutils              0.2.0
# ipywidgets                    7.6.5
# jupyter                       1.0.0
# jupyter-client                6.1.12
# jupyter-console               6.4.0
# jupyter-core                  4.9.2
# jupyter-server                1.13.5
# jupyterlab                    3.3.2
# jupyterlab-pygments           0.1.2
# jupyterlab-server             2.10.3
# jupyterlab-widgets            1.0.0
# mypy-extensions               0.4.3
# numpy                         1.21.5
# numpydoc                      1.2
# openpyxl                      3.0.9
# py                            1.11.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pycodestyle                   2.7.0
# ...

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydataset

# %%
pydataset.data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
pydataset.data('mtcars')
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# ...

# %%
pydataset.data
# Out:
# <function pydataset.data(item=None, show_doc=False)>

# %%
pip list | findstr sci
# Out:
# scikit-image                  0.19.2
# scikit-learn                  1.0.2
# scikit-learn-intelex          2021.20220215.102710
# scipy                         1.7.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn.metrics

# %%
import pandas as pd

# %%
pd.DataFrame([1,2,3,4])
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
pd.DataFrame([[1,2,3,4],['a','b','c','d']])
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  a  b  c  d

# %%
pd.DataFrame([1,2,3,4],['a','b','c','d'])
# Out:
#    0
# a  1
# b  2
# c  3
# d  4

# %%
df=pd.DataFrame({'name':['김지훈','이유진','박동현','김민지'],  
             'english':[90,80,60,70],
             'math':[50,60,100,20]})

# %%
df
# Out:
#   name  english  math
# 0  김지훈       90    50
# 1  이유진       80    60
# 2  박동현       60   100
# 3  김민지       70    20

# %%
df['english']   #1차원 자료(시리즈)
# Out:
# 0    90
# 1    80
# 2    60
# 3    70
# Name: english, dtype: int64

# %%
df['math']     #1차원 자료(시리즈)
# Out:
# 0     50
# 1     60
# 2    100
# 3     20
# Name: math, dtype: int64

# %%
df[['english','math']]    #df
# Out:
#    english  math
# 0       90    50
# 1       80    60
# 2       60   100
# 3       70    20

# %%
df[['english']]
# Out:
#    english
# 0       90
# 1       80
# 2       60
# 3       70

# %%
pwd
# Out:
# 'C:\\Users\\user'

# %%
exam=pd.read_excel("excel_exam.xlsx")

# %%
exam.head()
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58
# 4   5      2    25       80       65

# %%
exam['math']
# Out:
# 0     50
# 1     60
# 2     45
# 3     30
# 4     25
# 5     50
# 6     80
# 7     90
# 8     20
# 9     50
# 10    65
# 11    45
# 12    46
# 13    48
# 14    75
# 15    58
# 16    65
# 17    80
# 18    89
# 19    78
# Name: math, dtype: int64

# %%
#수학평균
import numpy as np
np.mean(exam['math'])
# Out:
# 57.45

# %%
sum(exam['math'])/len(exam['math'])
# Out:
# 57.45

# %%
import numpy as np
np.mean(exam,axis=0)
# Out:
# id         10.50
# class       3.00
# math       57.45
# english    84.90
# science    59.45
# dtype: float64

# %%
exam.to_csv("csv_exam.csv")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
import pandas as pd

# %%
pd.read_csv('csv_exam.csv').iloc[ : ,1: ]
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
pd.read_csv("csv_exam.csv").iloc[:,1:]
exam.head()
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58
# 4   5      2    25       80       65

# %%
#객체.to_csv()
#pd.read()

# %%
exam=pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.to_csv("csv_excel.csv",index=False)
pd.read_csv("csv_excel.csv")
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam=pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.to_excel("csv_excel.xlsx",index=False)

# %%
exam[:2]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
exam.describe()
# Out:
#              id      class       math    english    science
# count  20.00000  20.000000  20.000000  20.000000  20.000000
# mean   10.50000   3.000000  57.450000  84.900000  59.450000
# std     5.91608   1.450953  20.299015  12.875517  25.292968
# min     1.00000   1.000000  20.000000  56.000000  12.000000
# 25%     5.75000   2.000000  45.750000  78.000000  45.000000
# 50%    10.50000   3.000000  54.000000  86.500000  62.500000
# 75%    15.25000   4.000000  75.750000  98.000000  78.000000
# max    20.00000   5.000000  90.000000  98.000000  98.000000

# %%
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.rename({"english":"eng"},axis=1)
# Out:
#     id  class  math  eng  science
# 0    1      1    50   98       50
# 1    2      1    60   97       60
# 2    3      1    45   86       78
# 3    4      1    30   98       58
# 4    5      2    25   80       65
# 5    6      2    50   89       98
# 6    7      2    80   90       45
# 7    8      2    90   78       25
# 8    9      3    20   98       15
# 9   10      3    50   98       45
# 10  11      3    65   65       65
# 11  12      3    45   85       32
# 12  13      4    46   98       65
# 13  14      4    48   87       12
# 14  15      4    75   56       78
# 15  16      4    58   98       65
# 16  17      5    65   68       98
# 17  18      5    80   78       90
# 18  19      5    89   68       87
# 19  20      5    78   83       58

# %%
exam.rename(columns={"english":"eng"})
# Out:
#     id  class  math  eng  science
# 0    1      1    50   98       50
# 1    2      1    60   97       60
# 2    3      1    45   86       78
# 3    4      1    30   98       58
# 4    5      2    25   80       65
# 5    6      2    50   89       98
# 6    7      2    80   90       45
# 7    8      2    90   78       25
# 8    9      3    20   98       15
# 9   10      3    50   98       45
# 10  11      3    65   65       65
# 11  12      3    45   85       32
# 12  13      4    46   98       65
# 13  14      4    48   87       12
# 14  15      4    75   56       78
# 15  16      4    58   98       65
# 16  17      5    65   68       98
# 17  18      5    80   78       90
# 18  19      5    89   68       87
# 19  20      5    78   83       58

# %%
#emglish->eng
#science->sci

# %%
exam.rename({"english":"eng","science":"sci"},axis=1)
# Out:
#     id  class  math  eng  sci
# 0    1      1    50   98   50
# 1    2      1    60   97   60
# 2    3      1    45   86   78
# 3    4      1    30   98   58
# 4    5      2    25   80   65
# 5    6      2    50   89   98
# 6    7      2    80   90   45
# 7    8      2    90   78   25
# 8    9      3    20   98   15
# 9   10      3    50   98   45
# 10  11      3    65   65   65
# 11  12      3    45   85   32
# 12  13      4    46   98   65
# 13  14      4    48   87   12
# 14  15      4    75   56   78
# 15  16      4    58   98   65
# 16  17      5    65   68   98
# 17  18      5    80   78   90
# 18  19      5    89   68   87
# 19  20      5    78   83   58

# %%
exam.rename(columns={"english":"eng","science":"sci"},inplace=True)

# %%
import numpy as np

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pydataset

# %%
mpg=pydataset.data("mpg")

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
import seaborn as sns

# %%
exam=pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
ex=exam.copy

# %%
df['total']=exam['math']+exam['english']+exam['science']
df['mean']=(exam['math']+exam['english']+exam['science'])/3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [178], in <cell line: 1>()
# ----> 1 df['total']=exam['math']+exam['english']+exam['science']
#       2 df['mean']=(exam['math']+exam['english']+exam['science'])/3
#
# NameError: name 'df' is not defined

# %%
exam['total'] = exam['math'] + exam['english'] + exam['science']
exam['mean'] = (exam['math'] + exam['english'] + exam['science'])/3
exam['합격여부'] = np.where(exam['mean'] > 70, "합격", "불합격")
exam
# Out:
#     id  class  math  english  science  total       mean 합격여부
# 0    1      1    50       98       50    198  66.000000  불합격
# 1    2      1    60       97       60    217  72.333333   합격
# 2    3      1    45       86       78    209  69.666667  불합격
# 3    4      1    30       98       58    186  62.000000  불합격
# 4    5      2    25       80       65    170  56.666667  불합격
# 5    6      2    50       89       98    237  79.000000   합격
# 6    7      2    80       90       45    215  71.666667   합격
# 7    8      2    90       78       25    193  64.333333  불합격
# 8    9      3    20       98       15    133  44.333333  불합격
# 9   10      3    50       98       45    193  64.333333  불합격
# 10  11      3    65       65       65    195  65.000000  불합격
# 11  12      3    45       85       32    162  54.000000  불합격
# 12  13      4    46       98       65    209  69.666667  불합격
# 13  14      4    48       87       12    147  49.000000  불합격
# ...

# %%
mpg['total']=(mpg['cty']+mpg['hwy'])/2

# %%
#df["합격여부"]=np.where(df'[mean]>70,'합격','불합격')
# Out:
#   Input In [180]
#     df["합격여부"]=np.where(df'[mean]>70,'합격','불합격')
#                           ^
# SyntaxError: invalid syntax

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class  totoal  total
# 1    compact    32.5   23.5
# 2    compact    35.5   25.0
# ...

# %%
mpg=pydataset.data('mpg')
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact

# %%
mpg.info
# Out:
# <bound method DataFrame.info of     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ...

# %%
#countplot으로 drv칼럼을 그려보기~
sns.countplot(data=mpg,x='drv',hue='cyl')
#color:색깔
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
import seaborn as sns

# %%
#sns.countplot(dat=mpg,x='drv')

# %%
sns.countplot(data = mpg, x = 'drv')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='count'>

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
#total 열을 cty와 hwy평균으로
mpg['total'] = (mpg['cty'] + mpg['hwy']) /2
mpg['total'].describe()
# Out:
# count    234.000000
# mean      20.149573
# std        5.050290
# min       10.500000
# 25%       15.500000
# 50%       20.500000
# 75%       23.500000
# max       39.500000
# Name: total, dtype: float64

# %%
import numpy as np

# %%
np.min(mpg['total'])
np.max(mpg['total'])
# Out:
# 39.5

# %%
mpg['total'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
mpg['total'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## 시각화
# - matplotlib
# - seborn

# %%
sns.histplot(data=mpg, x='total', bins=7)
# Out:
# <AxesSubplot:xlabel='total', ylabel='Count'>

# %%
mpg['total'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.histplot(data = mpg, x = 'total', bins = 7)  #bin는 폭 조절이 가능하다.
# Out:
# <AxesSubplot:xlabel='total', ylabel='Count'>

# %%
mpg['total']
# Out:
# 1      23.5
# 2      25.0
# 3      25.5
# 4      25.5
# 5      21.0
#        ...
# 230    23.5
# 231    25.0
# 232    21.0
# 233    22.0
# 234    21.5
# Name: total, Length: 234, dtype: float64

# %%
mpg['test'] = np.where(mpg['total'] >= 20, 'pass', 'fail')
mpg[:2]
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
#
#    totoal  total  test
# 1    32.5   23.5  pass
# 2    35.5   25.0  pass

# %%
# test칼럼에 pass, fail의 빈도수
# c () : []
# table() : value_counts()

mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
test = mpg['test'].value_counts()
test.plot(kind = 'bar', rot = 0)
# Out:
# <AxesSubplot:>

# %%
mpg['test'].value_counts()
# Out:
# pass    128
# fail    106
# Name: test, dtype: int64

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(mpg['test'].value_counts())
df1
# Out:
#       test
# pass   128
# fail   106

# %%
df2 = df1.reset_index()
df2
# Out:
#   index  test
# 0  pass   128
# 1  fail   106

# %%
sns.barplot(data = df2, x = 'index', y = 'test')
# Out:
# <AxesSubplot:xlabel='index', ylabel='test'>

# %%
# mpg['grade']를 만들자.

'total'의 값이
30 이상이면 'A'
20 이상이면 'B'
그 이하면 'C' 으로 나눠보기.
mpg['grade']를 만들자.

# %%
mpg['grade'] = np.where(mpg['total'] >= 30, 'A', np.where(mpg['total'] >= 20, 'B', 'C'))

# %%
1) 'A','B','C'는 각각 몇 번 나오는가
2) 그 빈도수를 막대그래프로 그려보자

# %%
#1
grade = mpg['grade'].value_counts()

# %%
#2
grade.plot(kind = 'bar', rot=0)
# Out:
# <AxesSubplot:>

# %%
count_grade=mpg['grade'].value_counts().sort_index()
count_grade
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 count_grade=mpg['grade'].value_counts().sort_index()
#       2 count_grade
#
# NameError: name 'mpg' is not defined

# %% [markdown]
# # 9.21  p.132

# %%
import pandas as pd
exam=pd.read_excel("excel_exam.xlsx")
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam['class']
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
# 5     2
# 6     2
# 7     2
# 8     3
# 9     3
# 10    3
# 11    3
# 12    4
# 13    4
# 14    4
# 15    4
# 16    5
# 17    5
# 18    5
# 19    5
# Name: class, dtype: int64

# %%
#class==1을 찾아라
exam[exam['class']==1]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60
# 2   3      1    45       86       78
# 3   4      1    30       98       58

# %%
#math>=50을 찾아라
exam[exam['math']>=50]
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam[(exam['class']==1) & (exam['math']>=50)]   #괄호를 넣어줌
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
#exam[exam['class']==1) & (exam['math']>=50]    
                           
cond1=exam['class']==1      # cond라는 이름으로 조건을 지정해줌
cond2=exam['math']>=50

exam[cond1 & cond2]
# Out:
#    id  class  math  english  science
# 0   1      1    50       98       50
# 1   2      1    60       97       60

# %%
exam.query('math>=50')   #따음표는 문자열임 따음표 안에 한 문장이 들어가함
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.query('math>=50 and english>90')
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 9   10      3    50       98       45
# 15  16      4    58       98       65

# %%
exam.query('math>=50 or english>90')
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 3    4      1    30       98       58
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 12  13      4    46       98       65
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
#1반이면서 수학이 50점이상을 df.query()를 이용해 찾기
exam.rename({'class':'nclass'},axis=1,inplace=True)

# %%
exam.query('nclass==1 and math>=50')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam[(exam['nclass'] == 1) & (exam['math'] >= 50)]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %%
exam.query('nclass in [1,3,5]')

#[1,2,3,4,5] in [1,3,5]
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
df=pd.DataFrame({'sex': ['F','M','F','M'],
                'country':['Korea','China','Japen','USA']})
df
# Out:
#   sex country
# 0   F   Korea
# 1   M   China
# 2   F   Japen
# 3   M     USA

# %%
df.query('sex=="F" and country=="Korea"')  #p.142
# Out:
#   sex country
# 0   F   Korea

# %%
#p.145  필요한 변수 출력하기
exam.iloc[:,[2,3,4]]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam.iloc[:,2:]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam.iloc[:,[0,2,3]]
# Out:
#     id  math  english
# 0    1    50       98
# 1    2    60       97
# 2    3    45       86
# 3    4    30       98
# 4    5    25       80
# 5    6    50       89
# 6    7    80       90
# 7    8    90       78
# 8    9    20       98
# 9   10    50       98
# 10  11    65       65
# 11  12    45       85
# 12  13    46       98
# 13  14    48       87
# 14  15    75       56
# 15  16    58       98
# 16  17    65       68
# 17  18    80       78
# 18  19    89       68
# 19  20    78       83

# %%
exam.loc[:,['math','english','science']]
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %%
exam[:2]
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60

# %% [markdown]
# # 변수제거하기

# %%
exam.drop(['id','nclass'],axis=1)
# Out:
#     math  english  science
# 0     50       98       50
# 1     60       97       60
# 2     45       86       78
# 3     30       98       58
# 4     25       80       65
# 5     50       89       98
# 6     80       90       45
# 7     90       78       25
# 8     20       98       15
# 9     50       98       45
# 10    65       65       65
# 11    45       85       32
# 12    46       98       65
# 13    48       87       12
# 14    75       56       78
# 15    58       98       65
# 16    65       68       98
# 17    80       78       90
# 18    89       68       87
# 19    78       83       58

# %% [markdown]
# # 정렬 sort
# - sort_values()
# - sort_index()

# %%
exam.sort_values('math') #수학을 기준으로 오름차순
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 4    5       2    25       80       65
# 3    4       1    30       98       58
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 15  16       4    58       98       65
# 1    2       1    60       97       60
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 14  15       4    75       56       78
# 19  20       5    78       83       58
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 7    8       2    90       78       25

# %%
exam.sort_values('math',ascending=False)  #수학열을 기준으로 내림차순
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 6    7       2    80       90       45
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 0    1       1    50       98       50
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 11  12       3    45       85       32
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(['math','english'],ascending=False)  #수학열 기준
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
df=exam.sort_values(['math','english'],ascending=False) 
df
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 16  17       5    65       68       98
# 10  11       3    65       65       65
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 9   10       3    50       98       45
# 5    6       2    50       89       98
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %% [markdown]
# # 파생변수 추가하기

# %%
df.sort_index()    #index를 기준으로 정렬
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %% [markdown]
# # 새로운 변수 추가하기

# %%
#total이라는 math,english,science의 총합을 구해라(assign,mutate)
exam['total']=exam['math']+exam['english']+exam['science']
exam
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.assign(total1=exam['math']+exam['english']+exam['science'])
# Out:
#     id  nclass  math  english  science  total  total1
# 0    1       1    50       98       50    198     198
# 1    2       1    60       97       60    217     217
# 2    3       1    45       86       78    209     209
# 3    4       1    30       98       58    186     186
# 4    5       2    25       80       65    170     170
# 5    6       2    50       89       98    237     237
# 6    7       2    80       90       45    215     215
# 7    8       2    90       78       25    193     193
# 8    9       3    20       98       15    133     133
# 9   10       3    50       98       45    193     193
# 10  11       3    65       65       65    195     195
# 11  12       3    45       85       32    162     162
# 12  13       4    46       98       65    209     209
# 13  14       4    48       87       12    147     147
# 14  15       4    75       56       78    209     209
# 15  16       4    58       98       65    221     221
# ...

# %% [markdown]
# # 칼럼 추가하기

# %% [markdown]
# ### 집단별로 요약하기(group)

# %%
exam
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
exam.groupby('nclass')

# %%
list(exam.groupby('nclass'))  #20개가 반별로 묶어짐
# Out:
# [(1,
#      id  nclass  math  english  science  total
#   0   1       1    50       98       50    198
#   1   2       1    60       97       60    217
#   2   3       1    45       86       78    209
#   3   4       1    30       98       58    186),
#  (2,
#      id  nclass  math  english  science  total
#   4   5       2    25       80       65    170
#   5   6       2    50       89       98    237
#   6   7       2    80       90       45    215
#   7   8       2    90       78       25    193),
#  (3,
#       id  nclass  math  english  science  total
#   8    9       3    20       98       15    133
#   9   10       3    50       98       45    193
#   10  11       3    65       65       65    195
#   11  12       3    45       85       32    162),
#  (4,
#       id  nclass  math  english  science  total
#   12  13       4    46       98       65    209
#   13  14       4    48       87       12    147
#   14  15       4    75       56       78    209
# ...

# %%
exam.groupby('nclass').min()   #nclass별 최소값(반별 과목별 최소값)
# Out:
#         id  math  english  science  total
# nclass
# 1        1    30       86       50    186
# 2        5    25       78       25    170
# 3        9    20       65       15    133
# 4       13    46       56       12    147
# 5       17    65       68       58    219

# %%
exam.groupby('nclass').min()['math'] #수학의 최소값만 추출
# Out:
# nclass
# 1    30
# 2    25
# 3    20
# 4    46
# 5    65
# Name: math, dtype: int64

# %%
exam.groupby('nclass').min()[['math']]   #[]를 한번 더 하면 df형태로 나옴
# Out:
#         math
# nclass
# 1         30
# 2         25
# 3         20
# 4         46
# 5         65

# %%
exam.groupby('nclass').min()[['math','science']]
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
exam[['nclass','math','science']].groupby('nclass').min()
# Out:
#         math  science
# nclass
# 1         30       50
# 2         25       25
# 3         20       15
# 4         46       12
# 5         65       58

# %%
list(exam[['nclass','math','science']].groupby('nclass').min())
# Out:
# ['math', 'science']

# %%
pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # mpg불러오기~

# %%
#mpg불러오기~
import pydataset
mpg=pydataset.data('mpg')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# ## 집계함수 p.159
# #### drv와 class로 그룹을 짓고 각 그룹별 cty의 min()을 구하기~

# %%
mpg.groupby(['drv','class']).min()['cty']
# Out:
# drv  class
# 4    compact       15
#      midsize       15
#      pickup         9
#      subcompact    19
#      suv            9
# f    compact       16
#      midsize       16
#      minivan       11
#      subcompact    16
# r    2seater       15
#      subcompact    14
#      suv           11
# Name: cty, dtype: int64

# %%
mpg.groupby(['drv','class']).agg([min,max])
# Out:
#                manufacturer                           model  \
#                         min         max                 min
# drv class
# 4   compact            audi      subaru          a4 quattro
#     midsize            audi        audi          a6 quattro
#     pickup            dodge      toyota   dakota pickup 4wd
#     subcompact       subaru      subaru         impreza awd
#     suv           chevrolet      toyota         4runner 4wd
# f   compact            audi  volkswagen                  a4
#     midsize       chevrolet  volkswagen              altima
#     minivan           dodge       dodge         caravan 2wd
#     subcompact        honda  volkswagen               civic
# r   2seater       chevrolet   chevrolet            corvette
#     subcompact         ford        ford             mustang
#     suv           chevrolet     lincoln  c1500 suburban 2wd
#
#                                   displ       year       cyl         trans  \
# ...

# %%
mpg.groupby(['drv','class']).agg([min,max])['cty']
# Out:
#                 min  max
# drv class
# 4   compact      15   20
#     midsize      15   17
#     pickup        9   17
#     subcompact   19   21
#     suv           9   20
# f   compact      16   33
#     midsize      16   23
#     minivan      11   18
#     subcompact   16   35
# r   2seater      15   16
#     subcompact   14   18
#     suv          11   14

# %%
mpg.groupby(['drv','class']).apply(min)
# Out:
#                manufacturer               model  displ  year  cyl     trans  \
# drv class
# 4   compact            audi          a4 quattro    1.8  1999    4  auto(l5)
#     midsize            audi          a6 quattro    2.8  1999    6  auto(l5)
#     pickup            dodge   dakota pickup 4wd    2.7  1999    4  auto(l4)
#     subcompact       subaru         impreza awd    2.2  1999    4  auto(l4)
#     suv           chevrolet         4runner 4wd    2.5  1999    4  auto(l4)
# f   compact            audi                  a4    1.8  1999    4  auto(av)
#     midsize       chevrolet              altima    1.8  1999    4  auto(av)
#     minivan           dodge         caravan 2wd    2.4  1999    4  auto(l3)
#     subcompact        honda               civic    1.6  1999    4  auto(l4)
# r   2seater       chevrolet            corvette    5.7  1999    8  auto(l4)
#     subcompact         ford             mustang    3.8  1999    6  auto(l4)
# ...

# %%
mpg.groupby(['drv','class']).agg({'cty':min,'hwy':max})
# Out:
#                 cty  hwy
# drv class
# 4   compact      15   28
#     midsize      15   25
#     pickup        9   22
#     subcompact   19   26
#     suv           9   27
# f   compact      16   44
#     midsize      16   32
#     minivan      11   24
#     subcompact   16   44
# r   2seater      15   26
#     subcompact   14   26
#     suv          11   20

# %%
mpg.groupby(['drv','class']).agg(mean_cty=('cty','mean'))   #p.163
# Out:
#                  mean_cty
# drv class
# 4   compact     18.000000
#     midsize     16.000000
#     pickup      13.000000
#     subcompact  19.500000
#     suv         13.823529
# f   compact     20.857143
#     midsize     18.973684
#     minivan     15.818182
#     subcompact  22.363636
# r   2seater     15.400000
#     subcompact  15.888889
#     suv         12.000000

# %% [markdown]
# # 데이터프레임 합치기
# - merge
# - join
# - concat

# %%
test1=pd.DataFrame({'id' :[1,2,3,4,5],
                    'midterm' :[60,80,70,90,85]})
test2=pd.DataFrame({'id' :[1,2,3,6,7],
                    'final' :[70,83,65,98,80]})
print(test1)
test2
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   6     98
# 4   7     80

# %%
pd.merge(test1,test2)
# Out:
#    id  midterm  final
# 0   1       60     70
# 1   2       80     83
# 2   3       70     65

# %%
pd.merge(test1,test2,how='left',on='id')
# Out:
#    id  midterm  final
# 0   1       60   70.0
# 1   2       80   83.0
# 2   3       70   65.0
# 3   4       90    NaN
# 4   5       85    NaN

# %%
pd.merge(test1,test2,how='left')
# Out:
#    id  midterm  final
# 0   1       60   70.0
# 1   2       80   83.0
# 2   3       70   65.0
# 3   4       90    NaN
# 4   5       85    NaN

# %%
pd.merge(test1,test2,how='right')
# Out:
#    id  midterm  final
# 0   1     60.0     70
# 1   2     80.0     83
# 2   3     70.0     65
# 3   6      NaN     98
# 4   7      NaN     80

# %% [markdown]
# ### 지우기
# exam.drop('total',axis=1,inplace=True)

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
teacher=pd.DataFrame({'nclass':[1,2,3,4,5],
                    'teacher':['choi','park','hong','kim','jeong']})
teacher
# Out:
#    nclass teacher
# 0       1    choi
# 1       2    park
# 2       3    hong
# 3       4     kim
# 4       5   jeong

# %%
pd.merge(exam,teacher,on='nclass')
# Out:
#     id  nclass  math  english  science teacher
# 0    1       1    50       98       50    choi
# 1    2       1    60       97       60    choi
# 2    3       1    45       86       78    choi
# 3    4       1    30       98       58    choi
# 4    5       2    25       80       65    park
# 5    6       2    50       89       98    park
# 6    7       2    80       90       45    park
# 7    8       2    90       78       25    park
# 8    9       3    20       98       15    hong
# 9   10       3    50       98       45    hong
# 10  11       3    65       65       65    hong
# 11  12       3    45       85       32    hong
# 12  13       4    46       98       65     kim
# 13  14       4    48       87       12     kim
# 14  15       4    75       56       78     kim
# 15  16       4    58       98       65     kim
# 16  17       5    65       68       98   jeong
# 17  18       5    80       78       90   jeong
# 18  19       5    89       68       87   jeong
# ...

# %% [markdown]
# ## concat

# %%
pd.concat([test1,test2],axis=1)
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     98
# 4   5       85   7     80

# %%
pd.concat([test1,test2],axis=1,join='inner')
# Out:
#    id  midterm  id  final
# 0   1       60   1     70
# 1   2       80   2     83
# 2   3       70   3     65
# 3   4       90   6     98
# 4   5       85   7     80

# %% [markdown]
# ### 인덱스 바꾸기
# - set_index()
# - reset_index()
# - reindex()

# %%
test2
# Out:
#    id  final
# 0   1     70
# 1   2     83
# 2   3     65
# 3   6     98
# 4   7     80

# %%
test2.reindex([3,4,5,6,7])
# Out:
#     id  final
# 3  6.0   98.0
# 4  7.0   80.0
# 5  NaN    NaN
# 6  NaN    NaN
# 7  NaN    NaN

# %%
#이름바꾸기
test3=test2.rename({'final':'midterm'},axis=1)
test3
# Out:
#    id  midterm
# 0   1       70
# 1   2       83
# 2   3       65
# 3   6       98
# 4   7       80

# %%
pd.concat([test1,test3])   #NaN값이 사라짐
# Out:
#    id  midterm
# 0   1       60
# 1   2       80
# 2   3       70
# 3   4       90
# 4   5       85
# 0   1       70
# 1   2       83
# 2   3       65
# 3   6       98
# 4   7       80

# %%
group=pd.concat([test1,test3])

# %%
#id별로 midterm의 평균을 구해라
pd.concat([test1,test3]).groupby('id')['midterm'].mean()
# Out:
# id
# 1    65.0
# 2    81.5
# 3    67.5
# 4    90.0
# 5    85.0
# 6    98.0
# 7    80.0
# Name: midterm, dtype: float64

# %%
group.groupby('id')['midterm'].mean()
# Out:
# id
# 1    65.0
# 2    81.5
# 3    67.5
# 4    90.0
# 5    85.0
# 6    98.0
# 7    80.0
# Name: midterm, dtype: float64

# %%
group.groupby('id').mean()
# Out:
#     midterm
# id
# 1      65.0
# 2      81.5
# 3      67.5
# 4      90.0
# 5      85.0
# 6      98.0
# 7      80.0

# %%
import numpy as np
group.groupby('id').agg(np.mean)   #p176
# Out:
#     midterm
# id
# 1      65.0
# 2      81.5
# 3      67.5
# 4      90.0
# 5      85.0
# 6      98.0
# 7      80.0

# %%
mpg[['drv','cty']].groupby(['drv']).min()
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg.groupby(['drv']).min()[['cty']]
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %%
mpg.groupby(['drv'])[['cty']].min()
# Out:
#      cty
# drv
# 4      9
# f     11
# r     11

# %% [markdown]
# # 결측치

# %% [markdown]
# - 결측치 만들기 p.178

# %%
exam.iloc[0,2]=np.nan

# %%
exam.iloc[1,3]=np.nan
exam.iloc[2,4]=np.nan
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1   NaN     98.0     50.0
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %% [markdown]
# - 결측치 존재여부 확인하기

# %%
df=exam.copy()
pd.isna(df)
# Out:
#        id  nclass   math  english  science
# 0   False   False   True    False    False
# 1   False   False  False     True    False
# 2   False   False  False    False     True
# 3   False   False  False    False    False
# 4   False   False  False    False    False
# 5   False   False  False    False    False
# 6   False   False  False    False    False
# 7   False   False  False    False    False
# 8   False   False  False    False    False
# 9   False   False  False    False    False
# 10  False   False  False    False    False
# 11  False   False  False    False    False
# 12  False   False  False    False    False
# 13  False   False  False    False    False
# 14  False   False  False    False    False
# 15  False   False  False    False    False
# 16  False   False  False    False    False
# 17  False   False  False    False    False
# 18  False   False  False    False    False
# 19  False   False  False    False    False

# %% [markdown]
# - 결측치 개수 확인하기

# %%
pd.isna(df).sum()  #p.180
# Out:
# id         0
# nclass     0
# math       1
# english    1
# science    1
# dtype: int64

# %% [markdown]
# - 결측치 제거하기

# %%
df.dropna()
df
# Out:
#     id  nclass  math  english  science
# 0    1       1   NaN     98.0     50.0
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df.dropna(subset='math')  #math의 na
# Out:
#     id  nclass  math  english  science
# 1    2       1  60.0      NaN     60.0
# 2    3       1  45.0     86.0      NaN
# 3    4       1  30.0     98.0     58.0
# 4    5       2  25.0     80.0     65.0
# 5    6       2  50.0     89.0     98.0
# 6    7       2  80.0     90.0     45.0
# 7    8       2  90.0     78.0     25.0
# 8    9       3  20.0     98.0     15.0
# 9   10       3  50.0     98.0     45.0
# 10  11       3  65.0     65.0     65.0
# 11  12       3  45.0     85.0     32.0
# 12  13       4  46.0     98.0     65.0
# 13  14       4  48.0     87.0     12.0
# 14  15       4  75.0     56.0     78.0
# 15  16       4  58.0     98.0     65.0
# 16  17       5  65.0     68.0     98.0
# 17  18       5  80.0     78.0     90.0
# 18  19       5  89.0     68.0     87.0
# 19  20       5  78.0     83.0     58.0

# %%
df['math'].sum()
# Out:
# 1099.0

# %%
df['math'].mean()
# Out:
# 57.8421052631579

# %%
np.mean(df.math)
# Out:
# 57.8421052631579

# %%
df.apply(np.mean)
# Out:
# id         10.500000
# nclass      3.000000
# math       57.842105
# english    84.263158
# science    58.473684
# dtype: float64

# %%
df.iloc[0,2] = 57.842105
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %% [markdown]
# - 결측치 대체하기

# %%
m=df['math'].mean
m
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0     57.842105
# 1     60.000000
# 2     45.000000
# 3     30.000000
# 4     25.000000
# 5     50.000000
# 6     80.000000
# 7     90.000000
# 8     20.000000
# 9     50.000000
# 10    65.000000
# 11    45.000000
# 12    46.000000
# 13    48.000000
# 14    75.000000
# 15    58.000000
# 16    65.000000
# 17    80.000000
# 18    89.000000
# 19    78.000000
# Name: math, dtype: float64>

# %%
df['math']=df['math'].fillna(m)
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %%
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %%
df['english'].fillna(method='bfill',inplace=True)
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %%
s = df['science'].mean()
df['science'].fillna(s,inplace=True)
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %%
smean = np.mean(df['science'])
df['science'] = df['science'].fillna(smean)
df
# Out:
#     id  nclass       math  english    science
# 0    1       1  57.842105     98.0  50.000000
# 1    2       1  60.000000     10.0  60.000000
# 2    3       1  45.000000     86.0  58.473684
# 3    4       1  30.000000     98.0  58.000000
# 4    5       2  25.000000     80.0  65.000000
# 5    6       2  50.000000     89.0  98.000000
# 6    7       2  80.000000     90.0  45.000000
# 7    8       2  90.000000     78.0  25.000000
# 8    9       3  20.000000     98.0  15.000000
# 9   10       3  50.000000     98.0  45.000000
# 10  11       3  65.000000     65.0  65.000000
# 11  12       3  45.000000     85.0  32.000000
# 12  13       4  46.000000     98.0  65.000000
# 13  14       4  48.000000     87.0  12.000000
# 14  15       4  75.000000     56.0  78.000000
# 15  16       4  58.000000     98.0  65.000000
# 16  17       5  65.000000     68.0  98.000000
# 17  18       5  80.000000     78.0  90.000000
# 18  19       5  89.000000     68.0  87.000000
# ...

# %% [markdown]
# # 이상치 찾기(outlier) p.186

# %% [markdown]
# - 이상치 존재

# %%
df.iloc[0,2]=np.nan
df.iloc[1,3]=10
df
# Out:
#     id  nclass  math  english    science
# 0    1       1   NaN     98.0  50.000000
# 1    2       1  60.0     10.0  60.000000
# 2    3       1  45.0     86.0  58.473684
# 3    4       1  30.0     98.0  58.000000
# 4    5       2  25.0     80.0  65.000000
# 5    6       2  50.0     89.0  98.000000
# 6    7       2  80.0     90.0  45.000000
# 7    8       2  90.0     78.0  25.000000
# 8    9       3  20.0     98.0  15.000000
# 9   10       3  50.0     98.0  45.000000
# 10  11       3  65.0     65.0  65.000000
# 11  12       3  45.0     85.0  32.000000
# 12  13       4  46.0     98.0  65.000000
# 13  14       4  48.0     87.0  12.000000
# 14  15       4  75.0     56.0  78.000000
# 15  16       4  58.0     98.0  65.000000
# 16  17       5  65.0     68.0  98.000000
# 17  18       5  80.0     78.0  90.000000
# 18  19       5  89.0     68.0  87.000000
# 19  20       5  78.0     83.0  58.000000

# %%
import seaborn as sns
sns.boxplot(data=df,y='math')
# Out:
# <AxesSubplot:ylabel='math'>

# %% [markdown]
# # 9.22

# %%
import pandas as pd
exam=pd.read_excel("excel_exam.xlsx")

# %%
exam
# Out:
#     id  class  math  english  science
# 0    1      1    50       98       50
# 1    2      1    60       97       60
# 2    3      1    45       86       78
# 3    4      1    30       98       58
# 4    5      2    25       80       65
# 5    6      2    50       89       98
# 6    7      2    80       90       45
# 7    8      2    90       78       25
# 8    9      3    20       98       15
# 9   10      3    50       98       45
# 10  11      3    65       65       65
# 11  12      3    45       85       32
# 12  13      4    46       98       65
# 13  14      4    48       87       12
# 14  15      4    75       56       78
# 15  16      4    58       98       65
# 16  17      5    65       68       98
# 17  18      5    80       78       90
# 18  19      5    89       68       87
# 19  20      5    78       83       58

# %%
exam.rename({'class':'nclass'},axis=1,inplace=True)

# %%
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1     1       98       50
# 1    2       1    60        1       60
# 2    3       1    45       86        1
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
exam.iloc[0,2]=1
exam.iloc[1,3]=1
exam.iloc[2,4]=1
exam[:3]
# Out:
#    id  nclass  math  english  science
# 0   1       1     1       98       50
# 1   2       1    60        1       60
# 2   3       1    45       86        1

# %%
import seaborn as sns
sns.boxplot(data=exam,y='math')
# Out:
# <AxesSubplot:ylabel='math'>

# %% [markdown]
# # 이상치 p.190
# IQR: Inter Quartile Range 1사분위~3사분위
# #극단치
# 수염의 끝: 3사분위 + 1.5IQR
# 수염의 끝: 1사분위 - 1.5IQR

# %%
exam['math'].quantile(0.75)   #3사분위
# Out:
# 75.75

# %%
pct75=exam['math'].quantile(0.75)   #3사분위
pct25=exam['math'].quantile(0.25)  #1사분위
IQR=pct75-pct25
IQR
# Out:
# 30.75

# %%
pct75 + 1.5*IQR
pct25 - 1.5*IQR
# Out:
# -1.125

# %%
import pandas as pd
mpg=pd.read_csv("https://raw.githubusercontent.com/sidsriv/Introduction-to-Data-Science-in-python/master/mpg.csv")
mpg
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class
# 0     29  p  compact
# ...

# %%
mpg=mpg.iloc[:,1:]
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %%
#cty의 위쪽 수염의 극단치 값은 각각 얼마입니까?
pct75=exam['cty'].quantile(0.75)   #3사분위
pct25=exam['cty'].quantile(0.25)  #1사분위
pct75
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cty'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
pct25=mpg['cty'].quantile(.25)
pct25
# Out:
# 14.0

# %%
pct75=mpg['cty'].quantile(.75)
pct75
# Out:
# 19.0

# %%
iqr=pct75-pct25
iqr
# Out:
# 5.0

# %%
pct25-1.5*iqr
# Out:
# 6.5

# %%
pct75+1.5*iqr
# Out:
# 26.5

# %%
pct75=mpg['hwy'].quantile(0.75)  
pct25=mpg['hwy'].quantile(0.25)  
iqr=pct75-pct25
print(pct75+1.5*iqr)
pct25-1.5*iqr
# Out:
# 40.5
# 4.5

# %%
#hwy가 4.5이상, 4.0이하
mpg.query('hwy >= 40.5 | hwy <= 4.5')
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
#이상치를 제외한 hwy의 평균

# %%
cond1 = mpg.hwy >= 40.5
cond2 = mpg.hwy <= 4.5

mpg[cond1 | cond2]
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 212   volkswagen       jetta    1.9  1999    4  manual(m5)   f   33   44  d
# 221   volkswagen  new beetle    1.9  1999    4  manual(m5)   f   35   44  d
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
#
#           class
# 212     compact
# 221  subcompact
# 222  subcompact

# %%
mpg[~cond1| ~cond2].hwy.mean()
# Out:
# 23.44017094017094

# %%
sns.countplot(1차원)
sns.barplot(2차원)
sns.

# %%
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 0    compact
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# ..       ...
# ...

# %% [markdown]
# # 산점도 그리기

# %%
sns.scatterplot(data=mpg,x='displ',y='hwy',hue='drv')
# Out:
# <AxesSubplot:xlabel='displ', ylabel='hwy'>

# %%
sns.scatterplot(data=mpg,x='displ',y='hwy',hue='drv')\
.set(xlim=(3,6),ylim=(10,30))

plt.savefig("test.png",dpi=300)   #사진 저장하기(한 셀 안에 같이 넣어야 저장됨)

# %%
import matplotlib.pyplot as plt    #그림 크기 조정하기
plt.rcParams.update({'figure.figsize':[6,5]})

# %%
plt.savefig("test.png",dpi=300) #위에꺼랑 합쳐야 사진이 저장됨

# %%
#drv별로 hwy 주행연비의 평균 구하기

# %%
#방법1
df_mpg=mpg.groupby('drv').agg(mean_hwy=('hwy','mean'))
df_mpg
#방법2
df_mpg=mpg.groupby('drv')[['hwy']].mean()
df_mpg
# Out:
#            hwy
# drv
# 4    19.174757
# f    28.160377
# r    21.000000

# %%
df_mpg.index
# Out:
# Index(['4', 'f', 'r'], dtype='object', name='drv')

# %%
#인덱스를 칼럼으로 바꾸기
df_mpg.reset_index()
# Out:
#   drv        hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
sns.barplot(data=df_mpg.reset_index(),x='drv',y='hwy')  #p.206~
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
#groupby로 만들 때, 파라미터로 조건을 정하기
df_mpg=mpg.groupby('drv',as_index=False)[['hwy']].mean()
df_mpg
# Out:
#   drv        hwy
# 0   4  19.174757
# 1   f  28.160377
# 2   r  21.000000

# %%
df_mpg=df_mpg.sort_values(by='hwy',ascending=False)
df_mpg
# Out:
#   drv        hwy
# 1   f  28.160377
# 2   r  21.000000
# 0   4  19.174757

# %%
sns.barplot(data=df_mpg.sort_values(by='hwy',ascending=False),x='drv',y='hwy')
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %% [markdown]
# # 선그래프

# %%
import pydataset

# %%
pydataset.data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
economics=pydataset.data("economics")
economics[:2]
# Out:
#          date    pce     pop  psavert  uempmed  unemploy
# 1  1967-06-30  507.8  198712      9.8      4.5      2944
# 2  1967-07-31  510.9  198911      9.8      4.7      2945

# %%
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 26.1+ KB

# %%
sns.lineplot(data=economics,x='date',y='unemploy')
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %% [markdown]
# ### 칼럼의 데이터타입 바꾸기 astype()

# %%
economics['unemploy']=economics['unemploy'].astype('float')
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 42.3+ KB

# %%
economics['date']=economics['date'].astype('datetime64')
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    datetime64[ns]
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 42.3 KB

# %%
sns.lineplot(data=economics,x='date',y='unemploy')  #축에 연도 표시하기 p.214
# Out:
# <AxesSubplot:xlabel='date', ylabel='unemploy'>

# %%
economics['date']=economics['date'].astype('object')
economics.info()                                      #datetime 바꾸기 1번 방법
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    object
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 42.3+ KB

# %%
economics['date']=pd.to_datetime(economics['date'])
economics.info()                                      #datetime 바꾸기 2번 방법
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 478 entries, 1 to 478
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      478 non-null    datetime64[ns]
#  1   pce       478 non-null    float64
#  2   pop       478 non-null    int64
#  3   psavert   478 non-null    float64
#  4   uempmed   478 non-null    float64
#  5   unemploy  478 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 42.3 KB

# %% [markdown]
# ### 상자 수염그림

# %%
sns.boxplot(data=mpg,x='drv',y='hwy')   #변수가 x,y두개이어야 함
# Out:
# <AxesSubplot:xlabel='drv', ylabel='hwy'>

# %%
sns.boxplot(data=mpg,y='hwy')    #hwy의 칼럼에 대하여 변수1개
# Out:
# <AxesSubplot:ylabel='hwy'>

# %% [markdown]
# # 한국복지패널 데이터

# %%
pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyreadstat
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
raw_welfare=pd.read_spss("Koweps_hpwc14_2019_beta3.sav")
raw_welfare
# Out:
#        h14_id  h14_ind  h14_sn  h14_merkey  h_new  h14_cobf   p14_wsc  \
# 0         2.0      1.0     1.0     20101.0    0.0       NaN  0.291589
# 1         3.0      1.0     1.0     30101.0    0.0       NaN  0.419753
# 2         4.0      1.0     1.0     40101.0    0.0       NaN  0.265263
# 3         6.0      1.0     1.0     60101.0    0.0       NaN  0.494906
# 4         6.0      1.0     1.0     60101.0    0.0       NaN  1.017935
# ...       ...      ...     ...         ...    ...       ...       ...
# 14413  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14414  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14415  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14416  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
# 14417  9800.0      7.0     1.0  98000701.0    1.0       NaN       NaN
#
#         p14_wsl      p14_wgc      p14_wgl  ...  wc14_64  wc14_65  wc14_5aq4  \
# ...

# %%
welfare=raw_welfare.loc[:,['h14_g3':'sex',
                   'h14_g4':'birth',
                   'h14_g10':'marriage_type',
                   'h14_g11':'religion',
                   'p1402_8aq1':'code_job',
                   'h14_reg7':'code_region']]

welfare
# Out:
#   Input In [258]
#     welfare=raw_welfare.loc[:,['h14_g3':'sex',
#                                        ^
# SyntaxError: invalid syntax

# %%
welfare=raw_welfare.loc[:,['h14_g3',
                   'h14_g4',
                   'h14_g10',
                   'h14_g11',
                   'p1402_8aq1',
                   'h14_reg7']]

welfare
# Out:
#        h14_g3  h14_g4  h14_g10  h14_g11  p1402_8aq1  h14_reg7
# 0         2.0  1945.0      2.0      1.0         NaN       1.0
# 1         1.0  1948.0      2.0      2.0         NaN       1.0
# 2         1.0  1942.0      3.0      1.0       107.0       1.0
# 3         1.0  1962.0      1.0      1.0       192.0       1.0
# 4         2.0  1963.0      1.0      1.0         NaN       1.0
# ...       ...     ...      ...      ...         ...       ...
# 14413     2.0  1967.0      1.0      1.0         NaN       5.0
# 14414     2.0  1992.0      5.0      1.0         NaN       5.0
# 14415     1.0  1995.0      5.0      1.0         NaN       5.0
# 14416     2.0  1998.0      5.0      1.0       200.0       5.0
# 14417     1.0  2001.0      0.0      1.0         NaN       5.0
#
# [14418 rows x 6 columns]

# %%
welfare = welfare.rename(columns = {'h14_g3':'gender', 'h14_g4':'birth', 'h14_g10':'marriage_type',
                                    'h14_g11':'religion', 'p1402_8aq1':'income',
                                    'h14_eco9':'code_job', 'h14_reg7':'code_region'}) 
welfare
# Out:
#        gender   birth  marriage_type  religion  income  code_region
# 0         2.0  1945.0            2.0       1.0     NaN          1.0
# 1         1.0  1948.0            2.0       2.0     NaN          1.0
# 2         1.0  1942.0            3.0       1.0   107.0          1.0
# 3         1.0  1962.0            1.0       1.0   192.0          1.0
# 4         2.0  1963.0            1.0       1.0     NaN          1.0
# ...       ...     ...            ...       ...     ...          ...
# 14413     2.0  1967.0            1.0       1.0     NaN          5.0
# 14414     2.0  1992.0            5.0       1.0     NaN          5.0
# 14415     1.0  1995.0            5.0       1.0     NaN          5.0
# 14416     2.0  1998.0            5.0       1.0   200.0          5.0
# 14417     1.0  2001.0            0.0       1.0     NaN          5.0
#
# [14418 rows x 6 columns]

# %%
welfare[:2]
# Out:
#    gender   birth  marriage_type  religion  income  code_region
# 0     2.0  1945.0            2.0       1.0     NaN          1.0
# 1     1.0  1948.0            2.0       2.0     NaN          1.0

# %%
welfare['gender'].unique()
welfare['gender'].value_counts()
# Out:
# 2.0    7912
# 1.0    6506
# Name: gender, dtype: int64

# %%
#성별(gender)별로 월급(income)차이 p.229
welfare.groupby('gender')['income'].mean()
# Out:
# gender
# 1.0    349.037571
# 2.0    186.293096
# Name: income, dtype: float64

# %%
#gender에서 1은 male,2는 female로 바꾸어 주세요.
welfare['gender']=np.where(welfare['gender']==1,'male','female')
welfare[:4]
# Out:
#    gender   birth  marriage_type  religion  income  code_region
# 0  female  1945.0            2.0       1.0     NaN          1.0
# 1    male  1948.0            2.0       2.0     NaN          1.0
# 2    male  1942.0            3.0       1.0   107.0          1.0
# 3    male  1962.0            1.0       1.0   192.0          1.0

# %%
df=welfare.groupby('gender',as_index=False)[['income']].mean()
df
# Out:
#    gender      income
# 0  female  186.293096
# 1    male  349.037571

# %%
sns.barplot(data=df,x='gender',y='income')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='income'>

# %% [markdown]
# ### 나이별로 월급평균

# %%
welfare[:2]
# Out:
#    gender   birth  marriage_type  religion  income  code_region
# 0  female  1945.0            2.0       1.0     NaN          1.0
# 1    male  1948.0            2.0       2.0     NaN          1.0

# %%
min(welfare.birth)
max(welfare.birth)
# Out:
# 2018.0

# %%
2018년이 1살
2017년이 2살
2016년이 3살

age열을 만들어주세요

welfare['age']

# %%
welfare['age']=2019-welfare['birth']
welfare[:2]
# Out:
#    gender   birth  marriage_type  religion  income  code_region   age
# 0  female  1945.0            2.0       1.0     NaN          1.0  74.0
# 1    male  1948.0            2.0       2.0     NaN          1.0  71.0

# %%
welfare.isna().sum()
# Out:
# gender              0
# birth               0
# marriage_type       0
# religion            0
# income           9884
# code_region         0
# age                 0
# dtype: int64

# %%
#age열을 int로 바꾸어주세요
welfare['age']=welfare['age'].astype('int')
welfare['age']
# Out:
# 0        74
# 1        71
# 2        77
# 3        57
# 4        56
#          ..
# 14413    52
# 14414    27
# 14415    24
# 14416    21
# 14417    18
# Name: age, Length: 14418, dtype: int32

# %%
#나이별로 소득의 평균을 구해주세요
welfare.groupby(['age']).mean()[['income']]
# Out:
#          income
# age
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18   162.000000
# 19   121.333333
# 20   136.400000
# 21   123.666667
# 22   179.676471
# 23   143.742857
# 24   190.433333
# 25   190.430233
# 26   223.826667
# 27   220.616438
# 28   230.955556
# 29   247.696203
# 30   266.134831
# 31   276.297872
# 32   268.865385
# 33   281.176471
# 34   305.603175
# 35   302.467742
# 36   306.010870
# 37   334.539216
# 38   317.055556
# 39   341.694444
# 40   351.525424
# 41   324.137615
# 42   344.811881
# 43   386.195876
# 44   344.907563
# 45   350.511111
# 46   338.674419
# 47   379.827586
# 48   365.848485
# 49   368.539683
# 50   358.508772
# 51   310.400000
# 52   355.368421
# 53   339.379747
# 54   327.102564
# ...

# %%
df=welfare.groupby('age').agg('mean')[['income']]
df[:2]

'''
set_index
reset_index
reindex
'''
df = df.reset_index()
df
# Out:
#      age      income
# 0      1         NaN
# 1      2         NaN
# 2      3         NaN
# 3      4         NaN
# 4      5         NaN
# 5      6         NaN
# 6      7         NaN
# 7      8         NaN
# 8      9         NaN
# 9     10         NaN
# 10    11         NaN
# 11    12         NaN
# 12    13         NaN
# 13    14         NaN
# 14    15         NaN
# 15    16         NaN
# 16    17         NaN
# 17    18  162.000000
# 18    19  121.333333
# 19    20  136.400000
# 20    21  123.666667
# 21    22  179.676471
# 22    23  143.742857
# 23    24  190.433333
# 24    25  190.430233
# 25    26  223.826667
# 26    27  220.616438
# 27    28  230.955556
# 28    29  247.696203
# 29    30  266.134831
# 30    31  276.297872
# 31    32  268.865385
# 32    33  281.176471
# 33    34  305.603175
# 34    35  302.467742
# 35    36  306.010870
# 36    37  334.539216
# 37    38  317.055556
# 38    39  341.694444
# 39    40  351.525424
# 40    41  324.137615
# 41    42  344.811881
# ...

# %%
import pandas as pd
import numpy as np
df=welfare.groupby(['age']).agg('mean')[['income']]
df[:2]
# Out:
#      income
# age
# 1       NaN
# 2       NaN

# %%
#df로 lineplot그리기
sns.lineplot(data=df,x='age',y='income')
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %%
새 칼럼:age_gen
30이하:young
60이하:middle
나머지:old
# Out:
#   Input In [326]
#     새 칼럼:age_gen
#       ^
# SyntaxError: invalid syntax

# %%
welfare['age_gen']=np.where(welfare['age']<=30,'young',
                            np.where(welfare['age']<=60,'middle','old'))
welfare['age_gen']
# Out:
# 0           old
# 1           old
# 2           old
# 3        middle
# 4        middle
#           ...
# 14413    middle
# 14414     young
# 14415     young
# 14416     young
# 14417     young
# Name: age_gen, Length: 14418, dtype: object

# %%
welfare.age_gen.astype("category")   #카테고리형으러 바꾸기
welfare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14418 entries, 0 to 14417
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   gender         14418 non-null  object
#  1   birth          14418 non-null  float64
#  2   marriage_type  14418 non-null  float64
#  3   religion       14418 non-null  float64
#  4   income         4534 non-null   float64
#  5   code_region    14418 non-null  float64
#  6   age            14418 non-null  int32
#  7   age_gen        14418 non-null  object
# dtypes: float64(5), int32(1), object(2)
# memory usage: 844.9+ KB

# %%
#세대별 소득평균(income)
df_gen = welfare.groupby('age_gen')[['income']].mean() 
df_gen
# Out:
#              income
# age_gen
# middle   329.824855
# old      116.243770
# young    210.887097

# %%
#세대별,성별 소득평균
df_gen = welfare.groupby(['age_gen', 'gender'], as_index=False)[['income']].mean() 
df_gen
# Out:
#   age_gen  gender      income
# 0  middle  female  226.226646
# 1  middle    male  413.188540
# 2     old  female   81.132597
# 3     old    male  166.415789
# 4   young  female  198.790404
# 5   young    male  227.636364

# %%
df_gen = welfare.groupby(['age_gen', 'gender']).agg('mean')[['income']]
df_gen
# Out:
#                     income
# age_gen gender
# middle  female  226.226646
#         male    413.188540
# old     female   81.132597
#         male    166.415789
# young   female  198.790404
#         male    227.636364

# %%
df_gen=df_gen.reset_index()
df_gen
# Out:
#    level_0  index age_gen  gender      income
# 0        0      0  middle  female  226.226646
# 1        1      1  middle    male  413.188540
# 2        2      2     old  female   81.132597
# 3        3      3     old    male  166.415789
# 4        4      4   young  female  198.790404
# 5        5      5   young    male  227.636364

# %%
sns.barplot(data=df_gen,x='age_gen',y='income')
# Out:
# <AxesSubplot:xlabel='age_gen', ylabel='income'>

# %%
sns.barplot(data=df_gen,x='age_gen',y='income',hue='gender',order=['young','middle','old'])
# Out:
# <AxesSubplot:xlabel='age_gen', ylabel='income'>
